# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import pydot
import graphviz
from clr_callback import CyclicLR

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.python.client import device_lib 
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet101V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.models import save_model, load_model

tf.random.set_seed(42)

train_directory = "./data/organized/train/"
val_directory = "./data/organized/val/"
test_directory = "./data/organized/test/"

# %%
# Allow Tensorflow to allocate GPU memory as needed, rather than pre-allocating the entire GPU memory at the start of program execution.
# This option allows for better monitoring of system resource utilization.
physical_devices = tf.config.list_physical_devices('GPU')

tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
# Function to plot the resnet architecture.
# tf.keras.utils.plot_model(res101_base, show_shapes=True, expand_nested=True, show_dtype=True)

# %% [markdown]
# ### Creating tf datasets

# %%
# ===============================================================================================================
# This function creates training, validation and test datasets using the file structure created in the
# 01_create_train_val_test_directories notebook. 
# ===============================================================================================================
def create_tensorflow_datasets(image_size, train_directory, val_directory, test_directory, batch_size=32):
    
    train_dataset = image_dataset_from_directory(directory = train_directory,
                                                 labels='inferred',
                                                 label_mode = 'int',
                                                 image_size=image_size,
                                                 batch_size=batch_size,
                                                 smart_resize=True)

    val_dataset = image_dataset_from_directory(directory = val_directory,
                                               labels='inferred',
                                               label_mode = 'int',
                                               image_size=image_size,
                                               batch_size=batch_size,
                                               smart_resize=True)

    test_dataset = image_dataset_from_directory(directory = test_directory,
                                                labels = "inferred",
                                                label_mode = "int",
                                                image_size=image_size,
                                                batch_size=batch_size,
                                                smart_resize=True)
    
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = create_tensorflow_datasets(image_size=(520, 520),
                                                                      train_directory=train_directory,
                                                                      val_directory=val_directory,
                                                                      test_directory=test_directory,
                                                                      batch_size=32)
# Out:
# Found 10520 files belonging to 196 classes.
# Found 3234 files belonging to 196 classes.
# Found 2431 files belonging to 196 classes.

# %% [markdown]
# ### Resnet Modeling Functions

# %%
# ===============================================================================================================
# This function is used to instantiate either the Adam or RMSProp optimizers with the desired learning rate.
# ===============================================================================================================
def get_optimizer(optimizer_name, lr):
    
    if optimizer_name == 'rmsprop':
        
        optimizer = tf.keras.optimizers.RMSProp(learning_rate = lr)
    
    elif optimizer_name == 'adam':
        
        optimizer = tf.keras.optimizers.Adam(learning_rate = lr)
        
    return optimizer

# %%
# ===============================================================================================================
# This function is used to generate a unique filename to save the "best model" found during training.
# ===============================================================================================================
def get_model_save_path(optimizer, lr, epochs, batch_size, model_name):
    
    optimizer_string = "Adam_Cyclic_Decay_4e-4_4e-6"
    time_stamp = time.strftime("%Y_%m_%d-%H_%M_%S")
    
    model_save_path = os.path.join(os.getcwd(), f"trained_models/convnet/{time_stamp}_{model_name}_E{epochs}_O{optimizer_string}_B{batch_size}.keras")
    
    return model_save_path

# %%
# ===============================================================================================================
# This function insantiates and compiles a model that contains the following:
#
# 1. A pretrained Resnet101 base model with all weights frozen.
# 2. A set of keras preprocessing layers to perform random data augmentations.
# 3. A "model top" (output dense classifier) that needs to be trained.
# ===============================================================================================================
def build_resnet_classifier(input_shape, optimizer, learning_rate, metrics):
    
    
    optimizer = get_optimizer(optimizer, learning_rate)

    res101_base = keras.applications.ResNet101V2(weights='imagenet',
                                                 input_shape = input_shape,
                                                 include_top=False)
    
    # Freeze the resnet backbone.
    res101_base.trainable = False
    
    # Create a layer that is a set of data augmentations.
    data_augmentation = keras.Sequential([layers.experimental.preprocessing.RandomFlip("horizontal"),
                                          layers.experimental.preprocessing.RandomRotation(0.2),
                                          layers.experimental.preprocessing.RandomZoom(0.2),
                                          layers.experimental.preprocessing.RandomTranslation(height_factor=0.2,
                                                                                              width_factor=0.2)])
    
    # Input layer
    inputs = keras.Input(shape=input_shape)
    
    # Perform data augmentation
    x = data_augmentation(inputs)
    
    # Preprocess the images the way resnet101 expects them.
    x = preprocess_input(x)
    
    # Pass the input to the resnet101 backbone.
    # Setting training = False tells the resnet to run its forward pass in inference mode
    # rather than training mode.
    x = res101_base(x, training = False)
    
    x = layers.GlobalAvgPool2D()(x)
    
    x = layers.Flatten()(x)
    
    x = layers.Dense(480, activation='relu')(x)
    
    x = layers.Dropout(0.6)(x)
    
    outputs = layers.Dense(196, activation='softmax')(x)
    
    model = keras.Model(inputs, outputs)
    
    # Compile the model
    model.compile(loss = SparseCategoricalCrossentropy(),
                  optimizer=optimizer,
                  metrics=metrics)
    
    return model

# %%
# ===============================================================================================================
# This function is used for the following:
#
# 1. Setup callbacks and fit the model instantiated by the function above.
# 2. Save the model history attribtue after training is completed.
# ===============================================================================================================
def train_convnet_classifier(model, train_ds, val_ds, epochs=20, model_save_path=None):
    
    clr = CyclicLR(base_lr = 6e-6,
                   max_lr = 1.2e-3,
                   step_size = 1645,
                   mode='exp_range',
                   gamma=0.99997)
    
    callbacks = [keras.callbacks.ModelCheckpoint(filepath=model_save_path,
                                                 save_best_only=True,
                                                 monitor="val_loss",
                                                 verbose=1),
                 clr]
    
    history = model.fit(train_ds,
                        epochs=epochs,
                        validation_data=val_ds,
                        callbacks=callbacks)
    
    try:
        history_save_path = model_save_path.split(".")[0] + "_HISTORY.csv"
        df = pd.DataFrame(history.history)
        df.to_csv(history_save_path, index=False)
    except:
        print("Couldn't save history!")
        
    try:
        lr_history_save = model_save_path.split(".")[0] + "_LR_HISTORY.csv"
        df = pd.DataFrame(clr.history)
        df.to_csv(lr_history_save, index=False)
    except:
        print("Couldn't save LR history!!!")
        
    try:
        final_save_path = model_save_path.split(".")[0] + "_FINAL_SAVE.keras"
        save_model(model=model, filepath=final_save_path, overwrite=True, include_optimizer=True, save_format='tf')
    except:
        print("Couldn't save model!")
    
    return history, clr

# %%
# ===============================================================================================================
# This function takes as input a tensorflow dataset containing test data, and either a trained model
# or the path to where a trained model is located. 
#
# The function then evaluates the model using the test data and returns the associated test metrics.
# ===============================================================================================================
def test_convnet_classifier(test_ds, model=None, model_path=None):
    
    if model is not None:
        
        test_loss, test_acc = model.evaluate(test_ds)
        print("\n========================== Model Test Results ===============================")
        print(f"Test Accuracy: {test_acc}")
        print(f"Test Loss: {test_loss}")
        print("=============================================================================\n")
        
    elif model_path is not None:
        
        model = keras.models.load_model(model_path)
        test_loss, test_acc = model.evaluate(test_dataset)
        print("\n========================== Model Test Results ===============================")
        print(f"Test Accuracy: {test_acc}")
        print(f"Test Loss: {test_loss}")
        print("=============================================================================\n")
        
    else:
        print("\n========================== Error ===============================")
        print("Must pass either a trained model or a path to a trained model file.")
        print("Cannot have both model and model_path = None")
        print("=============================================================================\n")
        return -1
    
    return test_loss, test_acc, model

# %%
# ===============================================================================================================
# This function uses all the other functions defined above to drive the entire model training process.
# The full process implemented by this function is as follows:
#
# 1. Instantiate and compile the model using the build_convnet_classifier function.
# 2. Generate a uniue filepath to save the best model found during training.
# 3. Train the model and save the history attribute after training.
# 4. Evaluate the best model on the test data.
# ===============================================================================================================
def build_and_train_resnet(train_ds, val_ds, test_ds = None, input_shape=(520, 520, 3), optimizer='adam', metrics=['accuracy'],
                           epochs=20, batch_size=32, lr = 0.001, model_name = 'resnet101_ARCH2_LR_DECAY_CYCLIC'):
    
    
    # Build and compile the model 
    model = build_resnet_classifier(input_shape=input_shape, optimizer=optimizer, learning_rate=lr, metrics=metrics)
    
    print(model.summary())
    
    model_save_path = get_model_save_path(optimizer=optimizer, lr=lr, epochs=epochs, batch_size=batch_size, model_name=model_name)
    
    # Train the model
    training_history, learning_rate_history = train_convnet_classifier(model, train_ds, val_ds, epochs=epochs, model_save_path=model_save_path)
    
    if test_ds is not None:
        
        test_loss, test_acc, best_model = test_convnet_classifier(test_ds, model=None, model_path=model_save_path)
    
    return training_history, learning_rate_history, best_model

# %%
history, lr_history, model = build_and_train_resnet(train_ds=train_dataset,
                                         val_ds = val_dataset,
                                         test_ds = test_dataset,
                                         input_shape = (520, 520, 3),
                                         optimizer = 'adam',
                                         metrics=['accuracy'],
                                         lr = 6e-6,
                                         epochs=300,
                                         batch_size=32,
                                        model_name = 'LR_DECAY_1_2e-3_6e-6')
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 520, 520, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 520, 520, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 520, 520, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 520, 520, 3)       0
# _________________________________________________________________
# resnet101v2 (Functional)     (None, 17, 17, 2048)      42626560
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 480)               983520
# _________________________________________________________________
# dropout (Dropout)            (None, 480)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 196)               94276
# =================================================================
# Total params: 43,704,356
# Trainable params: 1,077,796
# Non-trainable params: 42,626,560
# _________________________________________________________________
# None
# Epoch 1/300
# 329/329 [==============================] - 227s 671ms/step - loss: 5.3482 - accuracy: 0.0068 - val_loss: 5.1736 - val_accuracy: 0.0266
#
# Epoch 00001: val_loss improved from inf to 5.17362, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# C:\Users\Braden\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/300
# 329/329 [==============================] - 219s 666ms/step - loss: 5.1392 - accuracy: 0.0190 - val_loss: 4.7377 - val_accuracy: 0.0711
#
# Epoch 00002: val_loss improved from 5.17362 to 4.73771, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 3/300
# 329/329 [==============================] - 219s 665ms/step - loss: 4.7879 - accuracy: 0.0386 - val_loss: 4.1997 - val_accuracy: 0.0952
#
# Epoch 00003: val_loss improved from 4.73771 to 4.19969, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 4/300
# 329/329 [==============================] - 219s 664ms/step - loss: 4.4562 - accuracy: 0.0646 - val_loss: 3.7981 - val_accuracy: 0.1494
#
# Epoch 00004: val_loss improved from 4.19969 to 3.79812, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 5/300
# 329/329 [==============================] - 219s 665ms/step - loss: 4.2408 - accuracy: 0.0812 - val_loss: 3.5381 - val_accuracy: 0.1707
#
# Epoch 00005: val_loss improved from 3.79812 to 3.53814, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 6/300
# 329/329 [==============================] - 220s 666ms/step - loss: 4.0326 - accuracy: 0.0966 - val_loss: 3.3458 - val_accuracy: 0.1892
#
# Epoch 00006: val_loss improved from 3.53814 to 3.34584, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 7/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.8279 - accuracy: 0.1272 - val_loss: 3.1421 - val_accuracy: 0.2313
#
# Epoch 00007: val_loss improved from 3.34584 to 3.14213, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 8/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.6796 - accuracy: 0.1394 - val_loss: 2.9828 - val_accuracy: 0.2579
#
# Epoch 00008: val_loss improved from 3.14213 to 2.98282, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 9/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.5246 - accuracy: 0.1632 - val_loss: 2.8890 - val_accuracy: 0.2863
#
# Epoch 00009: val_loss improved from 2.98282 to 2.88897, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 10/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4517 - accuracy: 0.1845 - val_loss: 2.8580 - val_accuracy: 0.2984
#
# Epoch 00010: val_loss improved from 2.88897 to 2.85804, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 11/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4296 - accuracy: 0.1856 - val_loss: 2.8515 - val_accuracy: 0.3061
#
# Epoch 00011: val_loss improved from 2.85804 to 2.85154, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 12/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4240 - accuracy: 0.1873 - val_loss: 2.8330 - val_accuracy: 0.3040
#
# Epoch 00012: val_loss improved from 2.85154 to 2.83304, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 13/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4285 - accuracy: 0.1795 - val_loss: 2.7814 - val_accuracy: 0.3120
#
# Epoch 00013: val_loss improved from 2.83304 to 2.78144, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 14/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4161 - accuracy: 0.1848 - val_loss: 2.7463 - val_accuracy: 0.2993
#
# Epoch 00014: val_loss improved from 2.78144 to 2.74628, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 15/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.4151 - accuracy: 0.1868 - val_loss: 2.6923 - val_accuracy: 0.3018
#
# Epoch 00015: val_loss improved from 2.74628 to 2.69226, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 16/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.3599 - accuracy: 0.1937 - val_loss: 2.5836 - val_accuracy: 0.3324
#
# Epoch 00016: val_loss improved from 2.69226 to 2.58357, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 17/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.2887 - accuracy: 0.2059 - val_loss: 2.5489 - val_accuracy: 0.3380
#
# Epoch 00017: val_loss improved from 2.58357 to 2.54887, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 18/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.1908 - accuracy: 0.2240 - val_loss: 2.4783 - val_accuracy: 0.3652
#
# Epoch 00018: val_loss improved from 2.54887 to 2.47826, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 19/300
# 329/329 [==============================] - 218s 661ms/step - loss: 3.0708 - accuracy: 0.2423 - val_loss: 2.4474 - val_accuracy: 0.3630
#
# Epoch 00019: val_loss improved from 2.47826 to 2.44739, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 20/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.0230 - accuracy: 0.2549 - val_loss: 2.4170 - val_accuracy: 0.3763
#
# Epoch 00020: val_loss improved from 2.44739 to 2.41695, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 21/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.9846 - accuracy: 0.2580 - val_loss: 2.4122 - val_accuracy: 0.3785
#
# Epoch 00021: val_loss improved from 2.41695 to 2.41218, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 22/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.0010 - accuracy: 0.2589 - val_loss: 2.4088 - val_accuracy: 0.3751
#
# Epoch 00022: val_loss improved from 2.41218 to 2.40882, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 23/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.0333 - accuracy: 0.2521 - val_loss: 2.4107 - val_accuracy: 0.3766
#
# Epoch 00023: val_loss did not improve from 2.40882
# Epoch 24/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.0731 - accuracy: 0.2468 - val_loss: 2.4266 - val_accuracy: 0.3587
#
# Epoch 00024: val_loss did not improve from 2.40882
# Epoch 25/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.1023 - accuracy: 0.2402 - val_loss: 2.3680 - val_accuracy: 0.3834
#
# Epoch 00025: val_loss improved from 2.40882 to 2.36803, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 26/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.0769 - accuracy: 0.2399 - val_loss: 2.3295 - val_accuracy: 0.3912
#
# Epoch 00026: val_loss improved from 2.36803 to 2.32950, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 27/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.0271 - accuracy: 0.2515 - val_loss: 2.2904 - val_accuracy: 0.4063
#
# Epoch 00027: val_loss improved from 2.32950 to 2.29039, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 28/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.9252 - accuracy: 0.2684 - val_loss: 2.2661 - val_accuracy: 0.4094
#
# Epoch 00028: val_loss improved from 2.29039 to 2.26609, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 29/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.8340 - accuracy: 0.2933 - val_loss: 2.2284 - val_accuracy: 0.4131
#
# Epoch 00029: val_loss improved from 2.26609 to 2.22842, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 30/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.7723 - accuracy: 0.3029 - val_loss: 2.2044 - val_accuracy: 0.4227
#
# Epoch 00030: val_loss improved from 2.22842 to 2.20439, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 31/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.7560 - accuracy: 0.3030 - val_loss: 2.2024 - val_accuracy: 0.4199
#
# Epoch 00031: val_loss improved from 2.20439 to 2.20238, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 32/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7919 - accuracy: 0.2983 - val_loss: 2.2234 - val_accuracy: 0.4177
#
# Epoch 00032: val_loss did not improve from 2.20238
# Epoch 33/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.8422 - accuracy: 0.2879 - val_loss: 2.2187 - val_accuracy: 0.4181
#
# Epoch 00033: val_loss did not improve from 2.20238
# Epoch 34/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.8533 - accuracy: 0.2804 - val_loss: 2.2480 - val_accuracy: 0.4079
#
# Epoch 00034: val_loss did not improve from 2.20238
# Epoch 35/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.8755 - accuracy: 0.2776 - val_loss: 2.2466 - val_accuracy: 0.3930
#
# Epoch 00035: val_loss did not improve from 2.20238
# Epoch 36/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.8790 - accuracy: 0.2814 - val_loss: 2.1746 - val_accuracy: 0.4230
#
# Epoch 00036: val_loss improved from 2.20238 to 2.17457, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 37/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.8124 - accuracy: 0.2918 - val_loss: 2.1584 - val_accuracy: 0.4295
#
# Epoch 00037: val_loss improved from 2.17457 to 2.15844, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 38/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.7490 - accuracy: 0.3056 - val_loss: 2.1173 - val_accuracy: 0.4338
#
# Epoch 00038: val_loss improved from 2.15844 to 2.11726, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 39/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.6670 - accuracy: 0.3248 - val_loss: 2.0748 - val_accuracy: 0.4508
#
# Epoch 00039: val_loss improved from 2.11726 to 2.07478, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 40/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.5861 - accuracy: 0.3363 - val_loss: 2.0600 - val_accuracy: 0.4462
#
# Epoch 00040: val_loss improved from 2.07478 to 2.06001, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 41/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.6028 - accuracy: 0.3332 - val_loss: 2.0773 - val_accuracy: 0.4437
#
# Epoch 00041: val_loss did not improve from 2.06001
# Epoch 42/300
# 329/329 [==============================] - 217s 660ms/step - loss: 2.6367 - accuracy: 0.3262 - val_loss: 2.0796 - val_accuracy: 0.4434
#
# Epoch 00042: val_loss did not improve from 2.06001
# Epoch 43/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.6750 - accuracy: 0.3200 - val_loss: 2.0800 - val_accuracy: 0.4459
#
# Epoch 00043: val_loss did not improve from 2.06001
# Epoch 44/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7066 - accuracy: 0.3128 - val_loss: 2.0946 - val_accuracy: 0.4351
#
# Epoch 00044: val_loss did not improve from 2.06001
# Epoch 45/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7447 - accuracy: 0.3020 - val_loss: 2.1105 - val_accuracy: 0.4286
#
# Epoch 00045: val_loss did not improve from 2.06001
# Epoch 46/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7318 - accuracy: 0.3047 - val_loss: 2.0882 - val_accuracy: 0.4397
#
# Epoch 00046: val_loss did not improve from 2.06001
# Epoch 47/300
# 329/329 [==============================] - 216s 657ms/step - loss: 2.6974 - accuracy: 0.3171 - val_loss: 2.0508 - val_accuracy: 0.4431
#
# Epoch 00047: val_loss improved from 2.06001 to 2.05077, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 48/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.6033 - accuracy: 0.3366 - val_loss: 2.0117 - val_accuracy: 0.4558
#
# Epoch 00048: val_loss improved from 2.05077 to 2.01170, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 49/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.5639 - accuracy: 0.3438 - val_loss: 1.9970 - val_accuracy: 0.4632
#
# Epoch 00049: val_loss improved from 2.01170 to 1.99700, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 50/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.5078 - accuracy: 0.3500 - val_loss: 1.9893 - val_accuracy: 0.4620
#
# Epoch 00050: val_loss improved from 1.99700 to 1.98928, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 51/300
# 329/329 [==============================] - 220s 666ms/step - loss: 2.4857 - accuracy: 0.3615 - val_loss: 1.9955 - val_accuracy: 0.4635
#
# Epoch 00051: val_loss did not improve from 1.98928
# Epoch 52/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4976 - accuracy: 0.3514 - val_loss: 2.0071 - val_accuracy: 0.4555
#
# Epoch 00052: val_loss did not improve from 1.98928
# Epoch 53/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.5355 - accuracy: 0.3502 - val_loss: 2.0109 - val_accuracy: 0.4675
#
# Epoch 00053: val_loss did not improve from 1.98928
# Epoch 54/300
# 329/329 [==============================] - 217s 660ms/step - loss: 2.5872 - accuracy: 0.3372 - val_loss: 2.0223 - val_accuracy: 0.4527
#
# Epoch 00054: val_loss did not improve from 1.98928
# Epoch 55/300
# 329/329 [==============================] - 218s 660ms/step - loss: 2.6301 - accuracy: 0.3219 - val_loss: 2.0459 - val_accuracy: 0.4388
#
# Epoch 00055: val_loss did not improve from 1.98928
# Epoch 56/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.6269 - accuracy: 0.3288 - val_loss: 2.0414 - val_accuracy: 0.4481
#
# Epoch 00056: val_loss did not improve from 1.98928
# Epoch 57/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5791 - accuracy: 0.3379 - val_loss: 1.9874 - val_accuracy: 0.4644
#
# Epoch 00057: val_loss improved from 1.98928 to 1.98744, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 58/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5063 - accuracy: 0.3496 - val_loss: 1.9679 - val_accuracy: 0.4651
#
# Epoch 00058: val_loss improved from 1.98744 to 1.96794, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 59/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.4701 - accuracy: 0.3676 - val_loss: 1.9322 - val_accuracy: 0.4697
#
# Epoch 00059: val_loss improved from 1.96794 to 1.93223, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 60/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4083 - accuracy: 0.3690 - val_loss: 1.9193 - val_accuracy: 0.4814
#
# Epoch 00060: val_loss improved from 1.93223 to 1.91929, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 61/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4179 - accuracy: 0.3764 - val_loss: 1.9258 - val_accuracy: 0.4814
#
# Epoch 00061: val_loss did not improve from 1.91929
# Epoch 62/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.4265 - accuracy: 0.3663 - val_loss: 1.9522 - val_accuracy: 0.4728
#
# Epoch 00062: val_loss did not improve from 1.91929
# Epoch 63/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.4898 - accuracy: 0.3515 - val_loss: 1.9661 - val_accuracy: 0.4663
#
# Epoch 00063: val_loss did not improve from 1.91929
# Epoch 64/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5049 - accuracy: 0.3521 - val_loss: 1.9531 - val_accuracy: 0.4663
#
# Epoch 00064: val_loss did not improve from 1.91929
# Epoch 65/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5109 - accuracy: 0.3484 - val_loss: 1.9820 - val_accuracy: 0.4613
#
# Epoch 00065: val_loss did not improve from 1.91929
# Epoch 66/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5361 - accuracy: 0.3437 - val_loss: 1.9419 - val_accuracy: 0.4700
#
# Epoch 00066: val_loss did not improve from 1.91929
# Epoch 67/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.4884 - accuracy: 0.3467 - val_loss: 1.9128 - val_accuracy: 0.4750
#
# Epoch 00067: val_loss improved from 1.91929 to 1.91285, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 68/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4364 - accuracy: 0.3644 - val_loss: 1.8850 - val_accuracy: 0.4833
#
# Epoch 00068: val_loss improved from 1.91285 to 1.88504, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 69/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.3684 - accuracy: 0.3824 - val_loss: 1.8918 - val_accuracy: 0.4790
#
# Epoch 00069: val_loss did not improve from 1.88504
# Epoch 70/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.3299 - accuracy: 0.3936 - val_loss: 1.8742 - val_accuracy: 0.4926
#
# Epoch 00070: val_loss improved from 1.88504 to 1.87425, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 71/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.3075 - accuracy: 0.3946 - val_loss: 1.8799 - val_accuracy: 0.4879
#
# Epoch 00071: val_loss did not improve from 1.87425
# Epoch 72/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.3663 - accuracy: 0.3815 - val_loss: 1.8848 - val_accuracy: 0.4802
#
# Epoch 00072: val_loss did not improve from 1.87425
# Epoch 73/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4091 - accuracy: 0.3702 - val_loss: 1.8968 - val_accuracy: 0.4845
#
# Epoch 00073: val_loss did not improve from 1.87425
# Epoch 74/300
# 329/329 [==============================] - 222s 673ms/step - loss: 2.4345 - accuracy: 0.3669 - val_loss: 1.8888 - val_accuracy: 0.4824
#
# Epoch 00074: val_loss did not improve from 1.87425
# Epoch 75/300
# 329/329 [==============================] - 226s 687ms/step - loss: 2.4522 - accuracy: 0.3590 - val_loss: 1.8978 - val_accuracy: 0.4842
#
# Epoch 00075: val_loss did not improve from 1.87425
# Epoch 76/300
# 329/329 [==============================] - 222s 673ms/step - loss: 2.4405 - accuracy: 0.3614 - val_loss: 1.8790 - val_accuracy: 0.4855
#
# Epoch 00076: val_loss did not improve from 1.87425
# Epoch 77/300
# 329/329 [==============================] - 224s 679ms/step - loss: 2.4047 - accuracy: 0.3717 - val_loss: 1.8384 - val_accuracy: 0.5003
#
# Epoch 00077: val_loss improved from 1.87425 to 1.83841, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 78/300
# 329/329 [==============================] - 221s 672ms/step - loss: 2.3748 - accuracy: 0.3788 - val_loss: 1.8564 - val_accuracy: 0.4935
#
# Epoch 00078: val_loss did not improve from 1.83841
# Epoch 79/300
# 329/329 [==============================] - 221s 670ms/step - loss: 2.3227 - accuracy: 0.3864 - val_loss: 1.8374 - val_accuracy: 0.4991
#
# Epoch 00079: val_loss improved from 1.83841 to 1.83739, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 80/300
# 329/329 [==============================] - 222s 674ms/step - loss: 2.2665 - accuracy: 0.3980 - val_loss: 1.8321 - val_accuracy: 0.5028
#
# Epoch 00080: val_loss improved from 1.83739 to 1.83206, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 81/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.2762 - accuracy: 0.4062 - val_loss: 1.8377 - val_accuracy: 0.5012
#
# Epoch 00081: val_loss did not improve from 1.83206
# Epoch 82/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.2908 - accuracy: 0.3949 - val_loss: 1.8437 - val_accuracy: 0.4913
#
# Epoch 00082: val_loss did not improve from 1.83206
# Epoch 83/300
# 329/329 [==============================] - 220s 669ms/step - loss: 2.3381 - accuracy: 0.3863 - val_loss: 1.8482 - val_accuracy: 0.4882
#
# Epoch 00083: val_loss did not improve from 1.83206
# Epoch 84/300
# 329/329 [==============================] - 221s 672ms/step - loss: 2.3361 - accuracy: 0.3933 - val_loss: 1.8542 - val_accuracy: 0.4833
#
# Epoch 00084: val_loss did not improve from 1.83206
# Epoch 85/300
# 329/329 [==============================] - 226s 685ms/step - loss: 2.3798 - accuracy: 0.3813 - val_loss: 1.8620 - val_accuracy: 0.4904
#
# Epoch 00085: val_loss did not improve from 1.83206
# Epoch 86/300
# 329/329 [==============================] - 222s 675ms/step - loss: 2.3616 - accuracy: 0.3829 - val_loss: 1.8553 - val_accuracy: 0.4858
#
# Epoch 00086: val_loss did not improve from 1.83206
# Epoch 87/300
# 329/329 [==============================] - 221s 672ms/step - loss: 2.3711 - accuracy: 0.3833 - val_loss: 1.8365 - val_accuracy: 0.4978
#
# Epoch 00087: val_loss did not improve from 1.83206
# Epoch 88/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.3339 - accuracy: 0.3865 - val_loss: 1.8235 - val_accuracy: 0.4978
#
# Epoch 00088: val_loss improved from 1.83206 to 1.82347, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 89/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.2682 - accuracy: 0.3997 - val_loss: 1.8163 - val_accuracy: 0.4985
#
# Epoch 00089: val_loss improved from 1.82347 to 1.81627, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 90/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.2206 - accuracy: 0.4165 - val_loss: 1.8119 - val_accuracy: 0.4991
#
# Epoch 00090: val_loss improved from 1.81627 to 1.81191, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 91/300
# 329/329 [==============================] - 222s 675ms/step - loss: 2.2146 - accuracy: 0.4118 - val_loss: 1.8110 - val_accuracy: 0.4963
#
# Epoch 00091: val_loss improved from 1.81191 to 1.81105, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 92/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.2466 - accuracy: 0.4067 - val_loss: 1.8192 - val_accuracy: 0.4963
#
# Epoch 00092: val_loss did not improve from 1.81105
# Epoch 93/300
# 329/329 [==============================] - 223s 676ms/step - loss: 2.2544 - accuracy: 0.4032 - val_loss: 1.8154 - val_accuracy: 0.4988
#
# Epoch 00093: val_loss did not improve from 1.81105
# Epoch 94/300
# 329/329 [==============================] - 222s 675ms/step - loss: 2.2946 - accuracy: 0.3972 - val_loss: 1.8242 - val_accuracy: 0.4975
#
# Epoch 00094: val_loss did not improve from 1.81105
# Epoch 95/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.3118 - accuracy: 0.3965 - val_loss: 1.8423 - val_accuracy: 0.4929
#
# Epoch 00095: val_loss did not improve from 1.81105
# Epoch 96/300
# 329/329 [==============================] - 224s 680ms/step - loss: 2.3105 - accuracy: 0.3928 - val_loss: 1.8191 - val_accuracy: 0.4963
#
# Epoch 00096: val_loss did not improve from 1.81105
# Epoch 97/300
# 329/329 [==============================] - 221s 671ms/step - loss: 2.2854 - accuracy: 0.4040 - val_loss: 1.8132 - val_accuracy: 0.4994
#
# Epoch 00097: val_loss did not improve from 1.81105
# Epoch 98/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.2459 - accuracy: 0.4116 - val_loss: 1.7930 - val_accuracy: 0.5009
#
# Epoch 00098: val_loss improved from 1.81105 to 1.79299, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 99/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.2137 - accuracy: 0.4165 - val_loss: 1.7806 - val_accuracy: 0.5053
#
# Epoch 00099: val_loss improved from 1.79299 to 1.78056, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 100/300
# 329/329 [==============================] - 222s 673ms/step - loss: 2.1823 - accuracy: 0.4221 - val_loss: 1.7699 - val_accuracy: 0.5121
#
# Epoch 00100: val_loss improved from 1.78056 to 1.76986, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 101/300
# 329/329 [==============================] - 226s 685ms/step - loss: 2.1707 - accuracy: 0.4180 - val_loss: 1.7820 - val_accuracy: 0.5071
#
# Epoch 00101: val_loss did not improve from 1.76986
# Epoch 102/300
# 329/329 [==============================] - 223s 678ms/step - loss: 2.2035 - accuracy: 0.4170 - val_loss: 1.7872 - val_accuracy: 0.5087
#
# Epoch 00102: val_loss did not improve from 1.76986
# Epoch 103/300
# 329/329 [==============================] - 225s 683ms/step - loss: 2.2210 - accuracy: 0.4098 - val_loss: 1.7855 - val_accuracy: 0.5025
#
# Epoch 00103: val_loss did not improve from 1.76986
# Epoch 104/300
# 329/329 [==============================] - 225s 684ms/step - loss: 2.2449 - accuracy: 0.4065 - val_loss: 1.8035 - val_accuracy: 0.5099
#
# Epoch 00104: val_loss did not improve from 1.76986
# Epoch 105/300
# 329/329 [==============================] - 221s 671ms/step - loss: 2.2755 - accuracy: 0.4003 - val_loss: 1.7865 - val_accuracy: 0.5043
#
# Epoch 00105: val_loss did not improve from 1.76986
# Epoch 106/300
# 329/329 [==============================] - 222s 672ms/step - loss: 2.2516 - accuracy: 0.4015 - val_loss: 1.7833 - val_accuracy: 0.5121
#
# Epoch 00106: val_loss did not improve from 1.76986
# Epoch 107/300
# 329/329 [==============================] - 221s 671ms/step - loss: 2.2329 - accuracy: 0.4039 - val_loss: 1.7708 - val_accuracy: 0.5121
#
# Epoch 00107: val_loss did not improve from 1.76986
# Epoch 108/300
# 329/329 [==============================] - 226s 687ms/step - loss: 2.1886 - accuracy: 0.4221 - val_loss: 1.7549 - val_accuracy: 0.5226
#
# Epoch 00108: val_loss improved from 1.76986 to 1.75491, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 109/300
# 329/329 [==============================] - 224s 681ms/step - loss: 2.1802 - accuracy: 0.4191 - val_loss: 1.7585 - val_accuracy: 0.5127
#
# Epoch 00109: val_loss did not improve from 1.75491
# Epoch 110/300
# 329/329 [==============================] - 223s 676ms/step - loss: 2.1587 - accuracy: 0.4321 - val_loss: 1.7509 - val_accuracy: 0.5176
#
# Epoch 00110: val_loss improved from 1.75491 to 1.75091, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 111/300
# 329/329 [==============================] - 223s 678ms/step - loss: 2.1395 - accuracy: 0.4300 - val_loss: 1.7523 - val_accuracy: 0.5148
#
# Epoch 00111: val_loss did not improve from 1.75091
# Epoch 112/300
# 329/329 [==============================] - 224s 680ms/step - loss: 2.1574 - accuracy: 0.4253 - val_loss: 1.7534 - val_accuracy: 0.5201
#
# Epoch 00112: val_loss did not improve from 1.75091
# Epoch 113/300
# 329/329 [==============================] - 224s 680ms/step - loss: 2.1603 - accuracy: 0.4274 - val_loss: 1.7722 - val_accuracy: 0.5108
#
# Epoch 00113: val_loss did not improve from 1.75091
# Epoch 114/300
# 329/329 [==============================] - 224s 681ms/step - loss: 2.2116 - accuracy: 0.4178 - val_loss: 1.7796 - val_accuracy: 0.5090
#
# Epoch 00114: val_loss did not improve from 1.75091
# Epoch 115/300
# 329/329 [==============================] - 222s 673ms/step - loss: 2.2165 - accuracy: 0.4134 - val_loss: 1.7825 - val_accuracy: 0.5145
#
# Epoch 00115: val_loss did not improve from 1.75091
# Epoch 116/300
# 329/329 [==============================] - 222s 675ms/step - loss: 2.2231 - accuracy: 0.4144 - val_loss: 1.7781 - val_accuracy: 0.5065
#
# Epoch 00116: val_loss did not improve from 1.75091
# Epoch 117/300
# 329/329 [==============================] - 226s 686ms/step - loss: 2.1877 - accuracy: 0.4213 - val_loss: 1.7634 - val_accuracy: 0.5090
#
# Epoch 00117: val_loss did not improve from 1.75091
# Epoch 118/300
# 329/329 [==============================] - 225s 683ms/step - loss: 2.1510 - accuracy: 0.4280 - val_loss: 1.7570 - val_accuracy: 0.5118
#
# Epoch 00118: val_loss did not improve from 1.75091
# Epoch 119/300
# 329/329 [==============================] - 226s 686ms/step - loss: 2.1552 - accuracy: 0.4299 - val_loss: 1.7502 - val_accuracy: 0.5179
#
# Epoch 00119: val_loss improved from 1.75091 to 1.75022, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 120/300
# 329/329 [==============================] - 226s 687ms/step - loss: 2.1143 - accuracy: 0.4322 - val_loss: 1.7452 - val_accuracy: 0.5192
#
# Epoch 00120: val_loss improved from 1.75022 to 1.74522, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 121/300
# 329/329 [==============================] - 227s 690ms/step - loss: 2.0942 - accuracy: 0.4428 - val_loss: 1.7465 - val_accuracy: 0.5173
#
# Epoch 00121: val_loss did not improve from 1.74522
# Epoch 122/300
# 329/329 [==============================] - 225s 682ms/step - loss: 2.1265 - accuracy: 0.4350 - val_loss: 1.7513 - val_accuracy: 0.5170
#
# Epoch 00122: val_loss did not improve from 1.74522
# Epoch 123/300
# 329/329 [==============================] - 224s 681ms/step - loss: 2.1416 - accuracy: 0.4297 - val_loss: 1.7548 - val_accuracy: 0.5167
#
# Epoch 00123: val_loss did not improve from 1.74522
# Epoch 124/300
# 329/329 [==============================] - 227s 690ms/step - loss: 2.1641 - accuracy: 0.4208 - val_loss: 1.7708 - val_accuracy: 0.5139
#
# Epoch 00124: val_loss did not improve from 1.74522
# Epoch 125/300
# 329/329 [==============================] - 226s 687ms/step - loss: 2.1913 - accuracy: 0.4233 - val_loss: 1.7620 - val_accuracy: 0.5093
#
# Epoch 00125: val_loss did not improve from 1.74522
# Epoch 126/300
# 329/329 [==============================] - 226s 686ms/step - loss: 2.1938 - accuracy: 0.4165 - val_loss: 1.7512 - val_accuracy: 0.5099
#
# Epoch 00126: val_loss did not improve from 1.74522
# Epoch 127/300
# 329/329 [==============================] - 224s 681ms/step - loss: 2.1652 - accuracy: 0.4209 - val_loss: 1.7407 - val_accuracy: 0.5111
#
# Epoch 00127: val_loss improved from 1.74522 to 1.74072, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 128/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.1017 - accuracy: 0.4372 - val_loss: 1.7330 - val_accuracy: 0.5173
#
# Epoch 00128: val_loss improved from 1.74072 to 1.73298, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 129/300
# 329/329 [==============================] - 221s 672ms/step - loss: 2.0972 - accuracy: 0.4370 - val_loss: 1.7273 - val_accuracy: 0.5201
#
# Epoch 00129: val_loss improved from 1.73298 to 1.72733, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 130/300
# 329/329 [==============================] - 222s 674ms/step - loss: 2.0619 - accuracy: 0.4484 - val_loss: 1.7252 - val_accuracy: 0.5198
#
# Epoch 00130: val_loss improved from 1.72733 to 1.72517, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 131/300
# 329/329 [==============================] - 220s 669ms/step - loss: 2.0729 - accuracy: 0.4449 - val_loss: 1.7281 - val_accuracy: 0.5176
#
# Epoch 00131: val_loss did not improve from 1.72517
# Epoch 132/300
# 329/329 [==============================] - 226s 686ms/step - loss: 2.0938 - accuracy: 0.4430 - val_loss: 1.7256 - val_accuracy: 0.5213
#
# Epoch 00132: val_loss did not improve from 1.72517
# Epoch 133/300
# 329/329 [==============================] - 224s 680ms/step - loss: 2.0870 - accuracy: 0.4473 - val_loss: 1.7312 - val_accuracy: 0.5201
#
# Epoch 00133: val_loss did not improve from 1.72517
# Epoch 134/300
# 329/329 [==============================] - 227s 688ms/step - loss: 2.1335 - accuracy: 0.4308 - val_loss: 1.7567 - val_accuracy: 0.5142
#
# Epoch 00134: val_loss did not improve from 1.72517
# Epoch 135/300
# 329/329 [==============================] - 225s 682ms/step - loss: 2.1670 - accuracy: 0.4202 - val_loss: 1.7727 - val_accuracy: 0.5096
#
# Epoch 00135: val_loss did not improve from 1.72517
# Epoch 136/300
# 329/329 [==============================] - 225s 684ms/step - loss: 2.1418 - accuracy: 0.4232 - val_loss: 1.7550 - val_accuracy: 0.5105
#
# Epoch 00136: val_loss did not improve from 1.72517
# Epoch 137/300
# 329/329 [==============================] - 220s 666ms/step - loss: 2.1226 - accuracy: 0.4358 - val_loss: 1.7278 - val_accuracy: 0.5278
#
# Epoch 00137: val_loss did not improve from 1.72517
# Epoch 138/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.1163 - accuracy: 0.4294 - val_loss: 1.7242 - val_accuracy: 0.5238
#
# Epoch 00138: val_loss improved from 1.72517 to 1.72423, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 139/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.0687 - accuracy: 0.4551 - val_loss: 1.7215 - val_accuracy: 0.5260
#
# Epoch 00139: val_loss improved from 1.72423 to 1.72145, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 140/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0854 - accuracy: 0.4433 - val_loss: 1.7177 - val_accuracy: 0.5269
#
# Epoch 00140: val_loss improved from 1.72145 to 1.71767, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 141/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0430 - accuracy: 0.4518 - val_loss: 1.7155 - val_accuracy: 0.5254
#
# Epoch 00141: val_loss improved from 1.71767 to 1.71548, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 142/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.0568 - accuracy: 0.4514 - val_loss: 1.7148 - val_accuracy: 0.5288
#
# Epoch 00142: val_loss improved from 1.71548 to 1.71477, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 143/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0561 - accuracy: 0.4466 - val_loss: 1.7231 - val_accuracy: 0.5201
#
# Epoch 00143: val_loss did not improve from 1.71477
# Epoch 144/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0887 - accuracy: 0.4460 - val_loss: 1.7277 - val_accuracy: 0.5204
#
# Epoch 00144: val_loss did not improve from 1.71477
# Epoch 145/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.1105 - accuracy: 0.4350 - val_loss: 1.7209 - val_accuracy: 0.5235
#
# Epoch 00145: val_loss did not improve from 1.71477
# Epoch 146/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.1237 - accuracy: 0.4375 - val_loss: 1.7352 - val_accuracy: 0.5204
#
# Epoch 00146: val_loss did not improve from 1.71477
# Epoch 147/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0793 - accuracy: 0.4382 - val_loss: 1.7333 - val_accuracy: 0.5220
#
# Epoch 00147: val_loss did not improve from 1.71477
# Epoch 148/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0516 - accuracy: 0.4477 - val_loss: 1.7140 - val_accuracy: 0.5291
#
# Epoch 00148: val_loss improved from 1.71477 to 1.71401, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 149/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.0052 - accuracy: 0.4638 - val_loss: 1.7050 - val_accuracy: 0.5272
#
# Epoch 00149: val_loss improved from 1.71401 to 1.70503, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 150/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0140 - accuracy: 0.4531 - val_loss: 1.6962 - val_accuracy: 0.5359
#
# Epoch 00150: val_loss improved from 1.70503 to 1.69624, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 151/300
# 329/329 [==============================] - 222s 674ms/step - loss: 2.0101 - accuracy: 0.4590 - val_loss: 1.7044 - val_accuracy: 0.5297
#
# Epoch 00151: val_loss did not improve from 1.69624
# Epoch 152/300
# 329/329 [==============================] - 220s 667ms/step - loss: 2.0197 - accuracy: 0.4529 - val_loss: 1.7098 - val_accuracy: 0.5300
#
# Epoch 00152: val_loss did not improve from 1.69624
# Epoch 153/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.0555 - accuracy: 0.4518 - val_loss: 1.7153 - val_accuracy: 0.5254
#
# Epoch 00153: val_loss did not improve from 1.69624
# Epoch 154/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.0656 - accuracy: 0.4447 - val_loss: 1.7186 - val_accuracy: 0.5260
#
# Epoch 00154: val_loss did not improve from 1.69624
# Epoch 155/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0738 - accuracy: 0.4426 - val_loss: 1.7258 - val_accuracy: 0.5220
#
# Epoch 00155: val_loss did not improve from 1.69624
# Epoch 156/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0759 - accuracy: 0.4463 - val_loss: 1.7257 - val_accuracy: 0.5244
#
# Epoch 00156: val_loss did not improve from 1.69624
# Epoch 157/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.0486 - accuracy: 0.4510 - val_loss: 1.7009 - val_accuracy: 0.5306
#
# ...
# Epoch 238/300
# 329/329 [==============================] - 222s 673ms/step - loss: 1.9078 - accuracy: 0.4814 - val_loss: 1.6331 - val_accuracy: 0.5498
#
# Epoch 00238: val_loss improved from 1.63748 to 1.63314, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 239/300
# 329/329 [==============================] - 221s 670ms/step - loss: 1.8963 - accuracy: 0.4849 - val_loss: 1.6352 - val_accuracy: 0.5516
#
# Epoch 00239: val_loss did not improve from 1.63314
# Epoch 240/300
# 329/329 [==============================] - 221s 670ms/step - loss: 1.8944 - accuracy: 0.4828 - val_loss: 1.6314 - val_accuracy: 0.5547
#
# Epoch 00240: val_loss improved from 1.63314 to 1.63140, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 241/300
# 329/329 [==============================] - 224s 678ms/step - loss: 1.8669 - accuracy: 0.4953 - val_loss: 1.6332 - val_accuracy: 0.5547
#
# Epoch 00241: val_loss did not improve from 1.63140
# Epoch 242/300
# 329/329 [==============================] - 223s 676ms/step - loss: 1.8766 - accuracy: 0.4875 - val_loss: 1.6346 - val_accuracy: 0.5513
#
# Epoch 00242: val_loss did not improve from 1.63140
# Epoch 243/300
# 329/329 [==============================] - 224s 679ms/step - loss: 1.8944 - accuracy: 0.4906 - val_loss: 1.6322 - val_accuracy: 0.5507
#
# Epoch 00243: val_loss did not improve from 1.63140
# Epoch 244/300
# 329/329 [==============================] - 223s 676ms/step - loss: 1.8895 - accuracy: 0.4865 - val_loss: 1.6310 - val_accuracy: 0.5510
#
# Epoch 00244: val_loss improved from 1.63140 to 1.63102, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 245/300
# 329/329 [==============================] - 221s 672ms/step - loss: 1.8780 - accuracy: 0.4894 - val_loss: 1.6393 - val_accuracy: 0.5523
#
# Epoch 00245: val_loss did not improve from 1.63102
# Epoch 246/300
# 329/329 [==============================] - 223s 676ms/step - loss: 1.8934 - accuracy: 0.4837 - val_loss: 1.6397 - val_accuracy: 0.5467
#
# Epoch 00246: val_loss did not improve from 1.63102
# Epoch 247/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.9153 - accuracy: 0.4752 - val_loss: 1.6358 - val_accuracy: 0.5495
#
# Epoch 00247: val_loss did not improve from 1.63102
# Epoch 248/300
# 329/329 [==============================] - 220s 668ms/step - loss: 1.8734 - accuracy: 0.4910 - val_loss: 1.6322 - val_accuracy: 0.5501
#
# Epoch 00248: val_loss did not improve from 1.63102
# Epoch 249/300
# 329/329 [==============================] - 219s 665ms/step - loss: 1.8682 - accuracy: 0.4864 - val_loss: 1.6338 - val_accuracy: 0.5479
#
# Epoch 00249: val_loss did not improve from 1.63102
# Epoch 250/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8750 - accuracy: 0.4935 - val_loss: 1.6331 - val_accuracy: 0.5513
#
# Epoch 00250: val_loss did not improve from 1.63102
# Epoch 251/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8670 - accuracy: 0.4917 - val_loss: 1.6333 - val_accuracy: 0.5519
#
# Epoch 00251: val_loss did not improve from 1.63102
# Epoch 252/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8835 - accuracy: 0.4913 - val_loss: 1.6310 - val_accuracy: 0.5529
#
# Epoch 00252: val_loss improved from 1.63102 to 1.63097, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 253/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8388 - accuracy: 0.5024 - val_loss: 1.6344 - val_accuracy: 0.5529
#
# Epoch 00253: val_loss did not improve from 1.63097
# Epoch 254/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8877 - accuracy: 0.4823 - val_loss: 1.6407 - val_accuracy: 0.5495
#
# Epoch 00254: val_loss did not improve from 1.63097
# Epoch 255/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.9033 - accuracy: 0.4826 - val_loss: 1.6375 - val_accuracy: 0.5448
#
# Epoch 00255: val_loss did not improve from 1.63097
# Epoch 256/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8923 - accuracy: 0.4906 - val_loss: 1.6407 - val_accuracy: 0.5461
#
# Epoch 00256: val_loss did not improve from 1.63097
# Epoch 257/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8940 - accuracy: 0.4866 - val_loss: 1.6286 - val_accuracy: 0.5510
#
# Epoch 00257: val_loss improved from 1.63097 to 1.62865, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 258/300
# 329/329 [==============================] - 218s 660ms/step - loss: 1.8775 - accuracy: 0.4812 - val_loss: 1.6297 - val_accuracy: 0.5566
#
# Epoch 00258: val_loss did not improve from 1.62865
# Epoch 259/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8870 - accuracy: 0.4905 - val_loss: 1.6252 - val_accuracy: 0.5535
#
# Epoch 00259: val_loss improved from 1.62865 to 1.62522, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 260/300
# 329/329 [==============================] - 218s 660ms/step - loss: 1.8487 - accuracy: 0.4997 - val_loss: 1.6269 - val_accuracy: 0.5557
#
# Epoch 00260: val_loss did not improve from 1.62522
# Epoch 261/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8596 - accuracy: 0.4973 - val_loss: 1.6278 - val_accuracy: 0.5507
#
# Epoch 00261: val_loss did not improve from 1.62522
# Epoch 262/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8665 - accuracy: 0.4907 - val_loss: 1.6264 - val_accuracy: 0.5507
#
# Epoch 00262: val_loss did not improve from 1.62522
# Epoch 263/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8557 - accuracy: 0.4912 - val_loss: 1.6315 - val_accuracy: 0.5482
#
# Epoch 00263: val_loss did not improve from 1.62522
# Epoch 264/300
# 329/329 [==============================] - 217s 659ms/step - loss: 1.8782 - accuracy: 0.4926 - val_loss: 1.6283 - val_accuracy: 0.5507
#
# Epoch 00264: val_loss did not improve from 1.62522
# Epoch 265/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8904 - accuracy: 0.4838 - val_loss: 1.6329 - val_accuracy: 0.5519
#
# Epoch 00265: val_loss did not improve from 1.62522
# Epoch 266/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8916 - accuracy: 0.4867 - val_loss: 1.6269 - val_accuracy: 0.5526
#
# Epoch 00266: val_loss did not improve from 1.62522
# Epoch 267/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8685 - accuracy: 0.4897 - val_loss: 1.6244 - val_accuracy: 0.5501
#
# Epoch 00267: val_loss improved from 1.62522 to 1.62442, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 268/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8682 - accuracy: 0.4933 - val_loss: 1.6248 - val_accuracy: 0.5557
#
# Epoch 00268: val_loss did not improve from 1.62442
# Epoch 269/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8620 - accuracy: 0.4971 - val_loss: 1.6254 - val_accuracy: 0.5584
#
# Epoch 00269: val_loss did not improve from 1.62442
# Epoch 270/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8683 - accuracy: 0.4913 - val_loss: 1.6250 - val_accuracy: 0.5581
#
# Epoch 00270: val_loss did not improve from 1.62442
# Epoch 271/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8455 - accuracy: 0.4918 - val_loss: 1.6245 - val_accuracy: 0.5588
#
# Epoch 00271: val_loss did not improve from 1.62442
# Epoch 272/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8389 - accuracy: 0.5017 - val_loss: 1.6273 - val_accuracy: 0.5560
#
# Epoch 00272: val_loss did not improve from 1.62442
# Epoch 273/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8496 - accuracy: 0.4971 - val_loss: 1.6236 - val_accuracy: 0.5532
#
# Epoch 00273: val_loss improved from 1.62442 to 1.62363, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 274/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8673 - accuracy: 0.4968 - val_loss: 1.6299 - val_accuracy: 0.5529
#
# Epoch 00274: val_loss did not improve from 1.62363
# Epoch 275/300
# 329/329 [==============================] - 218s 663ms/step - loss: 1.8712 - accuracy: 0.4933 - val_loss: 1.6287 - val_accuracy: 0.5523
#
# Epoch 00275: val_loss did not improve from 1.62363
# Epoch 276/300
# 329/329 [==============================] - 220s 668ms/step - loss: 1.8553 - accuracy: 0.4967 - val_loss: 1.6255 - val_accuracy: 0.5513
#
# Epoch 00276: val_loss did not improve from 1.62363
# Epoch 277/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.8560 - accuracy: 0.4960 - val_loss: 1.6227 - val_accuracy: 0.5535
#
# Epoch 00277: val_loss improved from 1.62363 to 1.62270, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 278/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.8712 - accuracy: 0.4996 - val_loss: 1.6230 - val_accuracy: 0.5532
#
# Epoch 00278: val_loss did not improve from 1.62270
# Epoch 279/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.8666 - accuracy: 0.4935 - val_loss: 1.6205 - val_accuracy: 0.5516
#
# Epoch 00279: val_loss improved from 1.62270 to 1.62047, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 280/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.8514 - accuracy: 0.4976 - val_loss: 1.6222 - val_accuracy: 0.5550
#
# Epoch 00280: val_loss did not improve from 1.62047
# Epoch 281/300
# 329/329 [==============================] - 219s 664ms/step - loss: 1.8414 - accuracy: 0.5009 - val_loss: 1.6220 - val_accuracy: 0.5572
#
# Epoch 00281: val_loss did not improve from 1.62047
# Epoch 282/300
# 329/329 [==============================] - 219s 665ms/step - loss: 1.8530 - accuracy: 0.4933 - val_loss: 1.6232 - val_accuracy: 0.5547
#
# Epoch 00282: val_loss did not improve from 1.62047
# Epoch 283/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8516 - accuracy: 0.5015 - val_loss: 1.6230 - val_accuracy: 0.5541
#
# Epoch 00283: val_loss did not improve from 1.62047
# Epoch 284/300
# 329/329 [==============================] - 218s 660ms/step - loss: 1.8284 - accuracy: 0.4979 - val_loss: 1.6239 - val_accuracy: 0.5529
#
# Epoch 00284: val_loss did not improve from 1.62047
# Epoch 285/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8832 - accuracy: 0.4888 - val_loss: 1.6221 - val_accuracy: 0.5581
#
# Epoch 00285: val_loss did not improve from 1.62047
# Epoch 286/300
# 329/329 [==============================] - 217s 660ms/step - loss: 1.8484 - accuracy: 0.5003 - val_loss: 1.6202 - val_accuracy: 0.5566
#
# Epoch 00286: val_loss improved from 1.62047 to 1.62019, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 287/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8502 - accuracy: 0.4938 - val_loss: 1.6234 - val_accuracy: 0.5547
#
# Epoch 00287: val_loss did not improve from 1.62019
# Epoch 288/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8686 - accuracy: 0.4903 - val_loss: 1.6224 - val_accuracy: 0.5516
#
# Epoch 00288: val_loss did not improve from 1.62019
# Epoch 289/300
# 329/329 [==============================] - 219s 665ms/step - loss: 1.8339 - accuracy: 0.5006 - val_loss: 1.6197 - val_accuracy: 0.5550
#
# Epoch 00289: val_loss improved from 1.62019 to 1.61973, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 290/300
# 329/329 [==============================] - 221s 671ms/step - loss: 1.8115 - accuracy: 0.5060 - val_loss: 1.6199 - val_accuracy: 0.5560
#
# Epoch 00290: val_loss did not improve from 1.61973
# Epoch 291/300
# 329/329 [==============================] - 223s 676ms/step - loss: 1.8313 - accuracy: 0.4996 - val_loss: 1.6196 - val_accuracy: 0.5569
#
# Epoch 00291: val_loss improved from 1.61973 to 1.61955, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 292/300
# 329/329 [==============================] - 222s 673ms/step - loss: 1.8596 - accuracy: 0.4946 - val_loss: 1.6210 - val_accuracy: 0.5538
#
# Epoch 00292: val_loss did not improve from 1.61955
# Epoch 293/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8675 - accuracy: 0.4892 - val_loss: 1.6163 - val_accuracy: 0.5526
#
# Epoch 00293: val_loss improved from 1.61955 to 1.61631, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_24-09_17_59_LR_DECAY_1_2e-3_6e-6_E300_OAdam_Cyclic_Decay_4e-4_4e-6_B32.keras
# Epoch 294/300
# 329/329 [==============================] - 222s 674ms/step - loss: 1.8304 - accuracy: 0.5010 - val_loss: 1.6209 - val_accuracy: 0.5510
#
# Epoch 00294: val_loss did not improve from 1.61631
# Epoch 295/300
# 329/329 [==============================] - 220s 667ms/step - loss: 1.8477 - accuracy: 0.4941 - val_loss: 1.6181 - val_accuracy: 0.5547
#
# Epoch 00295: val_loss did not improve from 1.61631
# Epoch 296/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8390 - accuracy: 0.4950 - val_loss: 1.6242 - val_accuracy: 0.5557
#
# Epoch 00296: val_loss did not improve from 1.61631
# Epoch 297/300
# 329/329 [==============================] - 218s 663ms/step - loss: 1.8195 - accuracy: 0.5070 - val_loss: 1.6182 - val_accuracy: 0.5541
#
# Epoch 00297: val_loss did not improve from 1.61631
# Epoch 298/300
# 329/329 [==============================] - 218s 661ms/step - loss: 1.8741 - accuracy: 0.4894 - val_loss: 1.6189 - val_accuracy: 0.5560
#
# Epoch 00298: val_loss did not improve from 1.61631
# Epoch 299/300
# 329/329 [==============================] - 220s 667ms/step - loss: 1.8187 - accuracy: 0.5022 - val_loss: 1.6195 - val_accuracy: 0.5553
#
# Epoch 00299: val_loss did not improve from 1.61631
# Epoch 300/300
# 329/329 [==============================] - 219s 666ms/step - loss: 1.8417 - accuracy: 0.4973 - val_loss: 1.6171 - val_accuracy: 0.5541
#
# Epoch 00300: val_loss did not improve from 1.61631
# 76/76 [==============================] - 40s 503ms/step - loss: 1.6061 - accuracy: 0.5660
#
# ========================== Model Test Results ===============================
# Test Accuracy: 0.5660222172737122
# Test Loss: 1.6060634851455688
# =============================================================================
