# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import time
import pydot
import graphviz

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.python.client import device_lib 
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet101V2
from tensorflow.keras.applications.resnet_v2 import preprocess_input
from tensorflow.keras.models import save_model, load_model

tf.random.set_seed(42)

train_directory = "./data/organized/train/"
val_directory = "./data/organized/val/"
test_directory = "./data/organized/test/"

# %%
# Allow Tensorflow to allocate GPU memory as needed, rather than pre-allocating the entire GPU memory at the start of program execution.
# This option allows for better monitoring of system resource utilization.
physical_devices = tf.config.list_physical_devices('GPU')

tf.config.experimental.set_memory_growth(physical_devices[0], enable=True)

# %%
# tf.keras.utils.plot_model(res101_base, show_shapes=True, expand_nested=True, show_dtype=True)

# %% [markdown]
# ### Creating tf datasets

# %%
# ===============================================================================================================
# This function creates training, validation and test datasets using the file structure created in the
# 01_create_train_val_test_directories notebook. 
# ===============================================================================================================
def create_tensorflow_datasets(image_size, train_directory, val_directory, test_directory, batch_size=32):
    
    train_dataset = image_dataset_from_directory(directory = train_directory,
                                                 labels='inferred',
                                                 label_mode = 'int',
                                                 image_size=image_size,
                                                 batch_size=batch_size,
                                                 smart_resize=True)

    val_dataset = image_dataset_from_directory(directory = val_directory,
                                               labels='inferred',
                                               label_mode = 'int',
                                               image_size=image_size,
                                               batch_size=batch_size,
                                               smart_resize=True)

    test_dataset = image_dataset_from_directory(directory = test_directory,
                                                labels = "inferred",
                                                label_mode = "int",
                                                image_size=image_size,
                                                batch_size=batch_size,
                                                smart_resize=True)
    
    return train_dataset, val_dataset, test_dataset

# %%
train_dataset, val_dataset, test_dataset = create_tensorflow_datasets(image_size=(520, 520),
                                                                      train_directory=train_directory,
                                                                      val_directory=val_directory,
                                                                      test_directory=test_directory,
                                                                      batch_size=32)
# Out:
# Found 10520 files belonging to 196 classes.
# Found 3234 files belonging to 196 classes.
# Found 2431 files belonging to 196 classes.

# %% [markdown]
# ### Custom Learning Rate Scheduler

# %%
# ===============================================================================================================
# Custom learning rate schedule. Updated by passing the function with keras.callbacks.LearningRateScheduler
# to model.fit
# ===============================================================================================================
def learning_rate_scheduler(epoch, lr):
    
    if epoch % 10 == 0 and epoch != 0:
        
        updated_lr = max((lr / (1 + 0.3)), 0.000001)
        
        if updated_lr != lr: 
            print("/n====================================================")
            print("Updating the learning rate...")
            print(f"Previous LR: {lr}  Updated LR: {updated_lr}")
            print("====================================================\n")
            
        return updated_lr 
    else:
        return lr

# %% [markdown]
# ### Resnet Modeling Functions

# %%
# ===============================================================================================================
# This function is used to instantiate either the Adam or RMSProp optimizers with the desired learning rate.
# ===============================================================================================================
def get_optimizer(optimizer_name, lr):
    
    if optimizer_name == 'rmsprop':
        
        optimizer = tf.keras.optimizers.RMSProp(learning_rate = lr)
    
    elif optimizer_name == 'adam':
        
        optimizer = tf.keras.optimizers.Adam(learning_rate = lr)
        
    return optimizer

# %%
# ===============================================================================================================
# This function is used to generate a unique filename to save the "best model" found during training.
# ===============================================================================================================
def get_model_save_path(optimizer, lr, epochs, batch_size, model_name):
    
    # String
    optimizer_string = optimizer + str(lr).split('.')[1]
    time_stamp = time.strftime("%Y_%m_%d-%H_%M_%S")
    
    model_save_path = os.path.join(os.getcwd(), f"trained_models/convnet/{time_stamp}_{model_name}_E{epochs}_O{optimizer_string}_B{batch_size}.keras")
    
    return model_save_path

# %%
# ===============================================================================================================
# This function insantiates and compiles a model that contains the following:
#
# 1. A pretrained Resnet101 base model with all weights frozen.
# 2. A set of keras preprocessing layers to perform random data augmentations.
# 3. A "model top" (output dense classifier) that needs to be trained.
# ===============================================================================================================
def build_resnet_classifier(input_shape, optimizer, learning_rate, metrics):
    
    
    optimizer = get_optimizer(optimizer, learning_rate)

    res101_base = keras.applications.ResNet101V2(weights='imagenet',
                                                 input_shape = input_shape,
                                                 include_top=False)
    
    # Freeze the resnet backbone.
    res101_base.trainable = False
    
    # Create a layer that is a set of data augmentations.
    data_augmentation = keras.Sequential([layers.experimental.preprocessing.RandomFlip("horizontal"),
                                          layers.experimental.preprocessing.RandomRotation(0.1),
                                          layers.experimental.preprocessing.RandomZoom(0.2)])
    
    # Input layer
    inputs = keras.Input(shape=input_shape)
    
    # Perform data augmentation
    x = data_augmentation(inputs)
    
    # Preprocess the images the way resnet101 expects them.
    x = preprocess_input(x)
    
    # Pass the input to the resnet101 backbone.
    # Setting training = False tells the resnet to run its forward pass in inference mode
    # rather than training mode.
    x = res101_base(x, training = False)
    
    x = layers.GlobalAvgPool2D()(x)
    
    x = layers.Flatten()(x)
    
    x = layers.Dense(256, activation='relu')(x)
    
    x = layers.Dropout(0.5)(x)
    
    outputs = layers.Dense(196, activation='softmax')(x)
    
    model = keras.Model(inputs, outputs)
    
    # Compile the model
    model.compile(loss = SparseCategoricalCrossentropy(),
                  optimizer=optimizer,
                  metrics=metrics)
    
    return model

# %%
# ===============================================================================================================
# This function is used for the following:
#
# 1. Setup callbacks and fit the model instantiated by the function above.
# 2. Save the model history attribtue after training is completed.
# ===============================================================================================================
def train_convnet_classifier(model, train_ds, val_ds, epochs=20, model_save_path=None):
    
    callbacks = [keras.callbacks.ModelCheckpoint(filepath=model_save_path,
                                                 save_best_only=True,
                                                 monitor="val_loss",
                                                 verbose=1),
                 keras.callbacks.EarlyStopping(monitor="val_loss",
                                               patience=20,
                                               verbose=1),
                 keras.callbacks.LearningRateScheduler(learning_rate_scheduler)]
    
    history = model.fit(train_ds,
                        epochs=epochs,
                        validation_data=val_ds,
                        callbacks=callbacks)
    
    try:
        history_save_path = model_save_path.split(".")[0] + "_HISTORY.csv"
        df = pd.DataFrame(history.history)
        df.to_csv(history_save_path, index=False)
    except:
        print("Couldn't save history!")
    
    try:
        final_save_path = model_save_path.split(".")[0] + "_FINAL_SAVE.keras"
        save_model(model=model, filepath=final_save_path, overwrite=True, include_optimizer=True, save_format='tf')
    except:
        print("Couldn't save model!")
    
    return history

# %%
# ===============================================================================================================
# This function takes as input a tensorflow dataset containing test data, and either a trained model
# or the path to where a trained model is located. 
#
# The function then evaluates the model using the test data and returns the associated test metrics.
# ===============================================================================================================
def test_convnet_classifier(test_ds, model=None, model_path=None):
    
    if model is not None:
        
        test_loss, test_acc = model.evaluate(test_ds)
        print("\n========================== Model Test Results ===============================")
        print(f"Test Accuracy: {test_acc}")
        print(f"Test Loss: {test_loss}")
        print("=============================================================================\n")
        
    elif model_path is not None:
        
        model = keras.models.load_model(model_path)
        test_loss, test_acc = model.evaluate(test_dataset)
        print("\n========================== Model Test Results ===============================")
        print(f"Test Accuracy: {test_acc}")
        print(f"Test Loss: {test_loss}")
        print("=============================================================================\n")
        
    else:
        print("\n========================== Error ===============================")
        print("Must pass either a trained model or a path to a trained model file.")
        print("Cannot have both model and model_path = None")
        print("=============================================================================\n")
        return -1
    
    return test_loss, test_acc, model

# %%
# ===============================================================================================================
# This function uses all the other functions defined above to drive the entire model training process.
# The full process implemented by this function is as follows:
#
# 1. Instantiate and compile the model using the build_convnet_classifier function.
# 2. Generate a uniue filepath to save the best model found during training.
# 3. Train the model and save the history attribute after training.
# 4. Evaluate the best model on the test data.
# ===============================================================================================================
def build_and_train_resnet(train_ds, val_ds, test_ds = None, input_shape=(520, 520, 3), optimizer='adam', metrics=['accuracy'],
                           epochs=20, batch_size=32, lr = 0.001, model_name = 'resnet101_arch1_lrdecay'):
    
    
    # Build and compile the model 
    model = build_resnet_classifier(input_shape=input_shape, optimizer=optimizer, learning_rate=lr, metrics=metrics)
    
    print(model.summary())
    
    model_save_path = get_model_save_path(optimizer=optimizer, lr=lr, epochs=epochs, batch_size=batch_size, model_name=model_name)
    
    # Train the model
    training_history = train_convnet_classifier(model, train_ds, val_ds, epochs=epochs, model_save_path=model_save_path)
    
    if test_ds is not None:
        
        test_loss, test_acc, best_model = test_convnet_classifier(test_ds, model=None, model_path=model_save_path)
    
    return training_history, best_model

# %%
history, model = build_and_train_resnet(train_ds=train_dataset,
                                         val_ds = val_dataset,
                                         test_ds = test_dataset,
                                         input_shape = (520, 520, 3),
                                         optimizer = 'adam',
                                         metrics=['accuracy'],
                                         lr = 0.001,
                                         epochs=300,
                                         batch_size=32)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 520, 520, 3)]     0
# _________________________________________________________________
# sequential (Sequential)      (None, 520, 520, 3)       0
# _________________________________________________________________
# tf.math.truediv (TFOpLambda) (None, 520, 520, 3)       0
# _________________________________________________________________
# tf.math.subtract (TFOpLambda (None, 520, 520, 3)       0
# _________________________________________________________________
# resnet101v2 (Functional)     (None, 17, 17, 2048)      42626560
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               524544
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 196)               50372
# =================================================================
# Total params: 43,201,476
# Trainable params: 574,916
# Non-trainable params: 42,626,560
# _________________________________________________________________
# None
# Epoch 1/300
# 329/329 [==============================] - 226s 667ms/step - loss: 5.1376 - accuracy: 0.0144 - val_loss: 4.6741 - val_accuracy: 0.0464
#
# Epoch 00001: val_loss improved from inf to 4.67413, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# C:\Users\Braden\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/300
# 329/329 [==============================] - 221s 671ms/step - loss: 4.5956 - accuracy: 0.0392 - val_loss: 4.0454 - val_accuracy: 0.1342
#
# Epoch 00002: val_loss improved from 4.67413 to 4.04537, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 3/300
# 329/329 [==============================] - 217s 659ms/step - loss: 4.2657 - accuracy: 0.0630 - val_loss: 3.6868 - val_accuracy: 0.1729
#
# Epoch 00003: val_loss improved from 4.04537 to 3.68676, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 4/300
# 329/329 [==============================] - 217s 659ms/step - loss: 4.0481 - accuracy: 0.0817 - val_loss: 3.4502 - val_accuracy: 0.2084
#
# Epoch 00004: val_loss improved from 3.68676 to 3.45024, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 5/300
# 329/329 [==============================] - 218s 661ms/step - loss: 3.8930 - accuracy: 0.0984 - val_loss: 3.2484 - val_accuracy: 0.2440
#
# Epoch 00005: val_loss improved from 3.45024 to 3.24842, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 6/300
# 329/329 [==============================] - 218s 660ms/step - loss: 3.7599 - accuracy: 0.1175 - val_loss: 3.1112 - val_accuracy: 0.2656
#
# Epoch 00006: val_loss improved from 3.24842 to 3.11120, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 7/300
# 329/329 [==============================] - 217s 660ms/step - loss: 3.6602 - accuracy: 0.1317 - val_loss: 3.0241 - val_accuracy: 0.2737
#
# Epoch 00007: val_loss improved from 3.11120 to 3.02407, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 8/300
# 329/329 [==============================] - 218s 662ms/step - loss: 3.5839 - accuracy: 0.1368 - val_loss: 2.9278 - val_accuracy: 0.2941
#
# Epoch 00008: val_loss improved from 3.02407 to 2.92780, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 9/300
# 329/329 [==============================] - 217s 658ms/step - loss: 3.5311 - accuracy: 0.1488 - val_loss: 2.8494 - val_accuracy: 0.3061
#
# Epoch 00009: val_loss improved from 2.92780 to 2.84943, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 10/300
# 329/329 [==============================] - 217s 657ms/step - loss: 3.4699 - accuracy: 0.1567 - val_loss: 2.7804 - val_accuracy: 0.3191
#
# Epoch 00010: val_loss improved from 2.84943 to 2.78040, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 11/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.0010000000474974513  Updated LR: 0.0007692308057672702
# ====================================================
#
# 329/329 [==============================] - 217s 659ms/step - loss: 3.4007 - accuracy: 0.1659 - val_loss: 2.7192 - val_accuracy: 0.3349
#
# Epoch 00011: val_loss improved from 2.78040 to 2.71919, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 12/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.3651 - accuracy: 0.1750 - val_loss: 2.6900 - val_accuracy: 0.3386
#
# Epoch 00012: val_loss improved from 2.71919 to 2.69000, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 13/300
# 329/329 [==============================] - 219s 665ms/step - loss: 3.3563 - accuracy: 0.1770 - val_loss: 2.6724 - val_accuracy: 0.3482
#
# Epoch 00013: val_loss improved from 2.69000 to 2.67237, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 14/300
# 329/329 [==============================] - 218s 662ms/step - loss: 3.2955 - accuracy: 0.1846 - val_loss: 2.6054 - val_accuracy: 0.3602
#
# Epoch 00014: val_loss improved from 2.67237 to 2.60543, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 15/300
# 329/329 [==============================] - 218s 663ms/step - loss: 3.2733 - accuracy: 0.1825 - val_loss: 2.5925 - val_accuracy: 0.3550
#
# Epoch 00015: val_loss improved from 2.60543 to 2.59249, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 16/300
# 329/329 [==============================] - 219s 664ms/step - loss: 3.2379 - accuracy: 0.1930 - val_loss: 2.5695 - val_accuracy: 0.3596
#
# Epoch 00016: val_loss improved from 2.59249 to 2.56949, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 17/300
# 329/329 [==============================] - 219s 666ms/step - loss: 3.2214 - accuracy: 0.1952 - val_loss: 2.5127 - val_accuracy: 0.3698
#
# Epoch 00017: val_loss improved from 2.56949 to 2.51266, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 18/300
# 329/329 [==============================] - 218s 661ms/step - loss: 3.1645 - accuracy: 0.2014 - val_loss: 2.4874 - val_accuracy: 0.3816
#
# Epoch 00018: val_loss improved from 2.51266 to 2.48741, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 19/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.1560 - accuracy: 0.2011 - val_loss: 2.4562 - val_accuracy: 0.3865
#
# Epoch 00019: val_loss improved from 2.48741 to 2.45616, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 20/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.1175 - accuracy: 0.2071 - val_loss: 2.4407 - val_accuracy: 0.3772
#
# Epoch 00020: val_loss improved from 2.45616 to 2.44066, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 21/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.0007692308281548321  Updated LR: 0.0005917160216575632
# ====================================================
#
# 329/329 [==============================] - 217s 659ms/step - loss: 3.0806 - accuracy: 0.2233 - val_loss: 2.3942 - val_accuracy: 0.4007
#
# Epoch 00021: val_loss improved from 2.44066 to 2.39416, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 22/300
# 329/329 [==============================] - 217s 659ms/step - loss: 3.0713 - accuracy: 0.2226 - val_loss: 2.3935 - val_accuracy: 0.3912
#
# Epoch 00022: val_loss improved from 2.39416 to 2.39345, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 23/300
# 329/329 [==============================] - 218s 662ms/step - loss: 3.0557 - accuracy: 0.2254 - val_loss: 2.3623 - val_accuracy: 0.4045
#
# Epoch 00023: val_loss improved from 2.39345 to 2.36235, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 24/300
# 329/329 [==============================] - 217s 660ms/step - loss: 3.0217 - accuracy: 0.2334 - val_loss: 2.3500 - val_accuracy: 0.4091
#
# Epoch 00024: val_loss improved from 2.36235 to 2.34998, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 25/300
# 329/329 [==============================] - 217s 660ms/step - loss: 3.0059 - accuracy: 0.2361 - val_loss: 2.3147 - val_accuracy: 0.4156
#
# Epoch 00025: val_loss improved from 2.34998 to 2.31467, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 26/300
# 329/329 [==============================] - 218s 662ms/step - loss: 3.0257 - accuracy: 0.2269 - val_loss: 2.3019 - val_accuracy: 0.4236
#
# Epoch 00026: val_loss improved from 2.31467 to 2.30189, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 27/300
# 329/329 [==============================] - 218s 660ms/step - loss: 2.9849 - accuracy: 0.2356 - val_loss: 2.2731 - val_accuracy: 0.4227
#
# Epoch 00027: val_loss improved from 2.30189 to 2.27311, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 28/300
# 329/329 [==============================] - 218s 660ms/step - loss: 2.9708 - accuracy: 0.2388 - val_loss: 2.2492 - val_accuracy: 0.4354
#
# Epoch 00028: val_loss improved from 2.27311 to 2.24925, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 29/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.9419 - accuracy: 0.2446 - val_loss: 2.2338 - val_accuracy: 0.4335
#
# Epoch 00029: val_loss improved from 2.24925 to 2.23383, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 30/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.9407 - accuracy: 0.2521 - val_loss: 2.2273 - val_accuracy: 0.4301
#
# Epoch 00030: val_loss improved from 2.23383 to 2.22730, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 31/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.0005917160306125879  Updated LR: 0.0004551661773942984
# ====================================================
#
# 329/329 [==============================] - 220s 667ms/step - loss: 2.9047 - accuracy: 0.2494 - val_loss: 2.2237 - val_accuracy: 0.4295
#
# Epoch 00031: val_loss improved from 2.22730 to 2.22374, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 32/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.8796 - accuracy: 0.2606 - val_loss: 2.2043 - val_accuracy: 0.4388
#
# Epoch 00032: val_loss improved from 2.22374 to 2.20434, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 33/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.8681 - accuracy: 0.2591 - val_loss: 2.1856 - val_accuracy: 0.4351
#
# Epoch 00033: val_loss improved from 2.20434 to 2.18563, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 34/300
# 329/329 [==============================] - 223s 677ms/step - loss: 2.8608 - accuracy: 0.2568 - val_loss: 2.1790 - val_accuracy: 0.4453
#
# Epoch 00034: val_loss improved from 2.18563 to 2.17901, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 35/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.8456 - accuracy: 0.2613 - val_loss: 2.1902 - val_accuracy: 0.4388
#
# Epoch 00035: val_loss did not improve from 2.17901
# Epoch 36/300
# 329/329 [==============================] - 219s 663ms/step - loss: 2.8368 - accuracy: 0.2613 - val_loss: 2.1623 - val_accuracy: 0.4465
#
# Epoch 00036: val_loss improved from 2.17901 to 2.16226, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 37/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.8387 - accuracy: 0.2643 - val_loss: 2.1589 - val_accuracy: 0.4453
#
# Epoch 00037: val_loss improved from 2.16226 to 2.15895, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 38/300
# 329/329 [==============================] - 216s 657ms/step - loss: 2.8199 - accuracy: 0.2691 - val_loss: 2.1422 - val_accuracy: 0.4524
#
# Epoch 00038: val_loss improved from 2.15895 to 2.14217, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 39/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.8144 - accuracy: 0.2690 - val_loss: 2.1124 - val_accuracy: 0.4589
#
# Epoch 00039: val_loss improved from 2.14217 to 2.11240, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 40/300
# 329/329 [==============================] - 220s 669ms/step - loss: 2.7803 - accuracy: 0.2755 - val_loss: 2.1250 - val_accuracy: 0.4533
#
# Epoch 00040: val_loss did not improve from 2.11240
# Epoch 41/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.000455166184110567  Updated LR: 0.00035012783393120533
# ====================================================
#
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7836 - accuracy: 0.2817 - val_loss: 2.1044 - val_accuracy: 0.4620
#
# Epoch 00041: val_loss improved from 2.11240 to 2.10438, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 42/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.7630 - accuracy: 0.2794 - val_loss: 2.0888 - val_accuracy: 0.4610
#
# Epoch 00042: val_loss improved from 2.10438 to 2.08885, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 43/300
# 329/329 [==============================] - 216s 655ms/step - loss: 2.7487 - accuracy: 0.2781 - val_loss: 2.0952 - val_accuracy: 0.4561
#
# Epoch 00043: val_loss did not improve from 2.08885
# Epoch 44/300
# 329/329 [==============================] - 215s 654ms/step - loss: 2.7659 - accuracy: 0.2810 - val_loss: 2.0831 - val_accuracy: 0.4623
#
# Epoch 00044: val_loss improved from 2.08885 to 2.08313, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 45/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.7419 - accuracy: 0.2762 - val_loss: 2.0744 - val_accuracy: 0.4601
#
# Epoch 00045: val_loss improved from 2.08313 to 2.07441, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 46/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.7327 - accuracy: 0.2874 - val_loss: 2.0683 - val_accuracy: 0.4567
#
# Epoch 00046: val_loss improved from 2.07441 to 2.06830, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 47/300
# 329/329 [==============================] - 225s 684ms/step - loss: 2.7307 - accuracy: 0.2961 - val_loss: 2.0568 - val_accuracy: 0.4691
#
# Epoch 00047: val_loss improved from 2.06830 to 2.05677, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 48/300
# 329/329 [==============================] - 220s 667ms/step - loss: 2.7127 - accuracy: 0.2916 - val_loss: 2.0522 - val_accuracy: 0.4669
#
# Epoch 00048: val_loss improved from 2.05677 to 2.05223, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 49/300
# 329/329 [==============================] - 223s 679ms/step - loss: 2.7197 - accuracy: 0.2907 - val_loss: 2.0391 - val_accuracy: 0.4641
#
# Epoch 00049: val_loss improved from 2.05223 to 2.03914, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 50/300
# 329/329 [==============================] - 221s 671ms/step - loss: 2.6980 - accuracy: 0.2910 - val_loss: 2.0367 - val_accuracy: 0.4682
#
# Epoch 00050: val_loss improved from 2.03914 to 2.03667, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 51/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.00035012784064747393  Updated LR: 0.00026932910819036455
# ====================================================
#
# 329/329 [==============================] - 221s 670ms/step - loss: 2.6888 - accuracy: 0.2922 - val_loss: 2.0455 - val_accuracy: 0.4675
#
# Epoch 00051: val_loss did not improve from 2.03667
# Epoch 52/300
# 329/329 [==============================] - 222s 674ms/step - loss: 2.6841 - accuracy: 0.2951 - val_loss: 2.0169 - val_accuracy: 0.4685
#
# Epoch 00052: val_loss improved from 2.03667 to 2.01691, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 53/300
# 329/329 [==============================] - 222s 672ms/step - loss: 2.6761 - accuracy: 0.2971 - val_loss: 2.0199 - val_accuracy: 0.4719
#
# Epoch 00053: val_loss did not improve from 2.01691
# Epoch 54/300
# 329/329 [==============================] - 222s 675ms/step - loss: 2.6601 - accuracy: 0.3075 - val_loss: 2.0252 - val_accuracy: 0.4669
#
# Epoch 00054: val_loss did not improve from 2.01691
# Epoch 55/300
# 329/329 [==============================] - 220s 667ms/step - loss: 2.6439 - accuracy: 0.3057 - val_loss: 2.0031 - val_accuracy: 0.4743
#
# Epoch 00055: val_loss improved from 2.01691 to 2.00308, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 56/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.6396 - accuracy: 0.3056 - val_loss: 2.0036 - val_accuracy: 0.4750
#
# Epoch 00056: val_loss did not improve from 2.00308
# Epoch 57/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.6467 - accuracy: 0.3027 - val_loss: 2.0004 - val_accuracy: 0.4811
#
# Epoch 00057: val_loss improved from 2.00308 to 2.00035, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 58/300
# 329/329 [==============================] - 216s 656ms/step - loss: 2.6312 - accuracy: 0.3045 - val_loss: 1.9965 - val_accuracy: 0.4805
#
# Epoch 00058: val_loss improved from 2.00035 to 1.99654, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 59/300
# 329/329 [==============================] - 216s 657ms/step - loss: 2.6111 - accuracy: 0.3189 - val_loss: 1.9892 - val_accuracy: 0.4780
#
# Epoch 00059: val_loss improved from 1.99654 to 1.98917, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 60/300
# 329/329 [==============================] - 216s 656ms/step - loss: 2.6299 - accuracy: 0.3085 - val_loss: 1.9822 - val_accuracy: 0.4873
#
# Epoch 00060: val_loss improved from 1.98917 to 1.98222, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 61/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.0002693291171453893  Updated LR: 0.00020717624395799177
# ====================================================
#
# 329/329 [==============================] - 217s 657ms/step - loss: 2.6069 - accuracy: 0.3142 - val_loss: 1.9699 - val_accuracy: 0.4842
#
# Epoch 00061: val_loss improved from 1.98222 to 1.96995, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 62/300
# 329/329 [==============================] - 216s 656ms/step - loss: 2.5904 - accuracy: 0.3135 - val_loss: 1.9642 - val_accuracy: 0.4855
#
# Epoch 00062: val_loss improved from 1.96995 to 1.96420, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 63/300
# 329/329 [==============================] - 216s 657ms/step - loss: 2.5953 - accuracy: 0.3205 - val_loss: 1.9612 - val_accuracy: 0.4833
#
# Epoch 00063: val_loss improved from 1.96420 to 1.96121, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 64/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.6003 - accuracy: 0.3189 - val_loss: 1.9682 - val_accuracy: 0.4858
#
# Epoch 00064: val_loss did not improve from 1.96121
# Epoch 65/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.6223 - accuracy: 0.3094 - val_loss: 1.9517 - val_accuracy: 0.4848
#
# Epoch 00065: val_loss improved from 1.96121 to 1.95173, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 66/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5989 - accuracy: 0.3137 - val_loss: 1.9522 - val_accuracy: 0.4898
#
# Epoch 00066: val_loss did not improve from 1.95173
# Epoch 67/300
# 329/329 [==============================] - 216s 654ms/step - loss: 2.5702 - accuracy: 0.3236 - val_loss: 1.9532 - val_accuracy: 0.4895
#
# Epoch 00067: val_loss did not improve from 1.95173
# Epoch 68/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5780 - accuracy: 0.3225 - val_loss: 1.9464 - val_accuracy: 0.4981
#
# Epoch 00068: val_loss improved from 1.95173 to 1.94636, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 69/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5912 - accuracy: 0.3214 - val_loss: 1.9571 - val_accuracy: 0.4879
#
# Epoch 00069: val_loss did not improve from 1.94636
# Epoch 70/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5917 - accuracy: 0.3187 - val_loss: 1.9573 - val_accuracy: 0.4901
#
# Epoch 00070: val_loss did not improve from 1.94636
# Epoch 71/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.0002071762428386137  Updated LR: 0.00015936634064508745
# ====================================================
#
# 329/329 [==============================] - 215s 654ms/step - loss: 2.5617 - accuracy: 0.3220 - val_loss: 1.9453 - val_accuracy: 0.4886
#
# Epoch 00071: val_loss improved from 1.94636 to 1.94532, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 72/300
# 329/329 [==============================] - 215s 654ms/step - loss: 2.5694 - accuracy: 0.3210 - val_loss: 1.9421 - val_accuracy: 0.4892
#
# Epoch 00072: val_loss improved from 1.94532 to 1.94213, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 73/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5499 - accuracy: 0.3306 - val_loss: 1.9227 - val_accuracy: 0.4920
#
# Epoch 00073: val_loss improved from 1.94213 to 1.92273, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 74/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5319 - accuracy: 0.3279 - val_loss: 1.9224 - val_accuracy: 0.4895
#
# Epoch 00074: val_loss improved from 1.92273 to 1.92236, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 75/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5351 - accuracy: 0.3250 - val_loss: 1.9124 - val_accuracy: 0.4913
#
# Epoch 00075: val_loss improved from 1.92236 to 1.91242, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 76/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5363 - accuracy: 0.3238 - val_loss: 1.9185 - val_accuracy: 0.4923
#
# Epoch 00076: val_loss did not improve from 1.91242
# Epoch 77/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5417 - accuracy: 0.3254 - val_loss: 1.9217 - val_accuracy: 0.4913
#
# Epoch 00077: val_loss did not improve from 1.91242
# Epoch 78/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5362 - accuracy: 0.3283 - val_loss: 1.9144 - val_accuracy: 0.4947
#
# Epoch 00078: val_loss did not improve from 1.91242
# Epoch 79/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5542 - accuracy: 0.3239 - val_loss: 1.9137 - val_accuracy: 0.5019
#
# Epoch 00079: val_loss did not improve from 1.91242
# Epoch 80/300
# 329/329 [==============================] - 215s 652ms/step - loss: 2.4992 - accuracy: 0.3381 - val_loss: 1.9101 - val_accuracy: 0.4935
#
# Epoch 00080: val_loss improved from 1.91242 to 1.91009, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 81/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.00015936634736135602  Updated LR: 0.00012258949797027386
# ====================================================
#
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5428 - accuracy: 0.3322 - val_loss: 1.9052 - val_accuracy: 0.4947
#
# Epoch 00081: val_loss improved from 1.91009 to 1.90522, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 82/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.4942 - accuracy: 0.3359 - val_loss: 1.9058 - val_accuracy: 0.5006
#
# Epoch 00082: val_loss did not improve from 1.90522
# Epoch 83/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.4986 - accuracy: 0.3353 - val_loss: 1.9008 - val_accuracy: 0.5012
#
# Epoch 00083: val_loss improved from 1.90522 to 1.90075, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 84/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5145 - accuracy: 0.3353 - val_loss: 1.9033 - val_accuracy: 0.5006
#
# Epoch 00084: val_loss did not improve from 1.90075
# Epoch 85/300
# 329/329 [==============================] - 215s 654ms/step - loss: 2.4911 - accuracy: 0.3357 - val_loss: 1.8951 - val_accuracy: 0.5074
#
# Epoch 00085: val_loss improved from 1.90075 to 1.89509, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 86/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.5059 - accuracy: 0.3296 - val_loss: 1.8959 - val_accuracy: 0.5037
#
# Epoch 00086: val_loss did not improve from 1.89509
# Epoch 87/300
# 329/329 [==============================] - 216s 656ms/step - loss: 2.4957 - accuracy: 0.3319 - val_loss: 1.8907 - val_accuracy: 0.5015
#
# Epoch 00087: val_loss improved from 1.89509 to 1.89067, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 88/300
# 329/329 [==============================] - 216s 656ms/step - loss: 2.5008 - accuracy: 0.3387 - val_loss: 1.8968 - val_accuracy: 0.4994
#
# Epoch 00088: val_loss did not improve from 1.89067
# Epoch 89/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.5161 - accuracy: 0.3355 - val_loss: 1.8922 - val_accuracy: 0.5034
#
# Epoch 00089: val_loss did not improve from 1.89067
# Epoch 90/300
# 329/329 [==============================] - 215s 653ms/step - loss: 2.5013 - accuracy: 0.3363 - val_loss: 1.8849 - val_accuracy: 0.5056
#
# Epoch 00090: val_loss improved from 1.89067 to 1.88485, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 91/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 0.00012258949573151767  Updated LR: 9.429961210116744e-05
# ====================================================
#
# 329/329 [==============================] - 215s 653ms/step - loss: 2.4876 - accuracy: 0.3424 - val_loss: 1.8815 - val_accuracy: 0.5105
#
# Epoch 00091: val_loss improved from 1.88485 to 1.88151, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 92/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4746 - accuracy: 0.3427 - val_loss: 1.8795 - val_accuracy: 0.5096
#
# Epoch 00092: val_loss improved from 1.88151 to 1.87948, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 93/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4751 - accuracy: 0.3426 - val_loss: 1.8802 - val_accuracy: 0.5068
#
# Epoch 00093: val_loss did not improve from 1.87948
# Epoch 94/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.4982 - accuracy: 0.3401 - val_loss: 1.8832 - val_accuracy: 0.5034
#
# Epoch 00094: val_loss did not improve from 1.87948
# Epoch 95/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4808 - accuracy: 0.3403 - val_loss: 1.8823 - val_accuracy: 0.5080
#
# Epoch 00095: val_loss did not improve from 1.87948
# Epoch 96/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4815 - accuracy: 0.3402 - val_loss: 1.8801 - val_accuracy: 0.5090
#
# Epoch 00096: val_loss did not improve from 1.87948
# Epoch 97/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4709 - accuracy: 0.3434 - val_loss: 1.8760 - val_accuracy: 0.5077
#
# Epoch 00097: val_loss improved from 1.87948 to 1.87599, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 98/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4713 - accuracy: 0.3460 - val_loss: 1.8702 - val_accuracy: 0.5121
#
# Epoch 00098: val_loss improved from 1.87599 to 1.87024, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 99/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4684 - accuracy: 0.3475 - val_loss: 1.8712 - val_accuracy: 0.5046
#
# Epoch 00099: val_loss did not improve from 1.87024
# Epoch 100/300
# 329/329 [==============================] - 218s 660ms/step - loss: 2.4722 - accuracy: 0.3405 - val_loss: 1.8718 - val_accuracy: 0.5074
#
# Epoch 00100: val_loss did not improve from 1.87024
# Epoch 101/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 9.429961210116744e-05  Updated LR: 7.253816315474418e-05
# ====================================================
#
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4407 - accuracy: 0.3512 - val_loss: 1.8660 - val_accuracy: 0.5093
#
# Epoch 00101: val_loss improved from 1.87024 to 1.86597, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 102/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.4689 - accuracy: 0.3451 - val_loss: 1.8671 - val_accuracy: 0.5074
#
# Epoch 00102: val_loss did not improve from 1.86597
# Epoch 103/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4659 - accuracy: 0.3512 - val_loss: 1.8615 - val_accuracy: 0.5040
#
# Epoch 00103: val_loss improved from 1.86597 to 1.86150, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 104/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4723 - accuracy: 0.3449 - val_loss: 1.8700 - val_accuracy: 0.5068
#
# Epoch 00104: val_loss did not improve from 1.86150
# Epoch 105/300
# 329/329 [==============================] - 217s 660ms/step - loss: 2.4401 - accuracy: 0.3492 - val_loss: 1.8600 - val_accuracy: 0.5071
#
# Epoch 00105: val_loss improved from 1.86150 to 1.86001, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 106/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.4507 - accuracy: 0.3475 - val_loss: 1.8664 - val_accuracy: 0.5071
#
# Epoch 00106: val_loss did not improve from 1.86001
# Epoch 107/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.4510 - accuracy: 0.3440 - val_loss: 1.8613 - val_accuracy: 0.5065
#
# Epoch 00107: val_loss did not improve from 1.86001
# Epoch 108/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4501 - accuracy: 0.3451 - val_loss: 1.8565 - val_accuracy: 0.5096
#
# Epoch 00108: val_loss improved from 1.86001 to 1.85645, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 109/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4381 - accuracy: 0.3509 - val_loss: 1.8610 - val_accuracy: 0.5056
#
# Epoch 00109: val_loss did not improve from 1.85645
# Epoch 110/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4518 - accuracy: 0.3468 - val_loss: 1.8576 - val_accuracy: 0.5118
#
# Epoch 00110: val_loss did not improve from 1.85645
# Epoch 111/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 7.253816147567704e-05  Updated LR: 5.57985857505208e-05
# ====================================================
#
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4492 - accuracy: 0.3487 - val_loss: 1.8588 - val_accuracy: 0.5118
#
# Epoch 00111: val_loss did not improve from 1.85645
# Epoch 112/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4462 - accuracy: 0.3475 - val_loss: 1.8563 - val_accuracy: 0.5114
#
# Epoch 00112: val_loss improved from 1.85645 to 1.85627, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 113/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4446 - accuracy: 0.3450 - val_loss: 1.8554 - val_accuracy: 0.5093
#
# Epoch 00113: val_loss improved from 1.85627 to 1.85540, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 114/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4265 - accuracy: 0.3521 - val_loss: 1.8569 - val_accuracy: 0.5083
#
# Epoch 00114: val_loss did not improve from 1.85540
# Epoch 115/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4438 - accuracy: 0.3467 - val_loss: 1.8543 - val_accuracy: 0.5124
#
# Epoch 00115: val_loss improved from 1.85540 to 1.85430, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 116/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.4417 - accuracy: 0.3493 - val_loss: 1.8542 - val_accuracy: 0.5080
#
# Epoch 00116: val_loss improved from 1.85430 to 1.85416, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 117/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4473 - accuracy: 0.3454 - val_loss: 1.8521 - val_accuracy: 0.5093
#
# Epoch 00117: val_loss improved from 1.85416 to 1.85209, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 118/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.4213 - accuracy: 0.3547 - val_loss: 1.8466 - val_accuracy: 0.5136
#
# Epoch 00118: val_loss improved from 1.85209 to 1.84664, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 119/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4436 - accuracy: 0.3470 - val_loss: 1.8472 - val_accuracy: 0.5111
#
# Epoch 00119: val_loss did not improve from 1.84664
# Epoch 120/300
# 329/329 [==============================] - 217s 660ms/step - loss: 2.4267 - accuracy: 0.3549 - val_loss: 1.8502 - val_accuracy: 0.5096
#
# Epoch 00120: val_loss did not improve from 1.84664
# Epoch 121/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 5.579858407145366e-05  Updated LR: 4.292198774727205e-05
# ====================================================
#
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4165 - accuracy: 0.3557 - val_loss: 1.8436 - val_accuracy: 0.5068
#
# Epoch 00121: val_loss improved from 1.84664 to 1.84361, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 122/300
# 329/329 [==============================] - 222s 673ms/step - loss: 2.4270 - accuracy: 0.3583 - val_loss: 1.8452 - val_accuracy: 0.5090
#
# Epoch 00122: val_loss did not improve from 1.84361
# Epoch 123/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.3930 - accuracy: 0.3582 - val_loss: 1.8376 - val_accuracy: 0.5099
#
# Epoch 00123: val_loss improved from 1.84361 to 1.83762, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 124/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4054 - accuracy: 0.3502 - val_loss: 1.8414 - val_accuracy: 0.5164
#
# Epoch 00124: val_loss did not improve from 1.83762
# Epoch 125/300
# 329/329 [==============================] - 216s 657ms/step - loss: 2.4061 - accuracy: 0.3597 - val_loss: 1.8382 - val_accuracy: 0.5148
#
# Epoch 00125: val_loss did not improve from 1.83762
# Epoch 126/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4312 - accuracy: 0.3487 - val_loss: 1.8384 - val_accuracy: 0.5108
#
# Epoch 00126: val_loss did not improve from 1.83762
# Epoch 127/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.4159 - accuracy: 0.3624 - val_loss: 1.8421 - val_accuracy: 0.5130
#
# Epoch 00127: val_loss did not improve from 1.83762
# Epoch 128/300
# 329/329 [==============================] - 218s 662ms/step - loss: 2.4149 - accuracy: 0.3563 - val_loss: 1.8389 - val_accuracy: 0.5148
#
# Epoch 00128: val_loss did not improve from 1.83762
# Epoch 129/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4042 - accuracy: 0.3597 - val_loss: 1.8419 - val_accuracy: 0.5155
#
# Epoch 00129: val_loss did not improve from 1.83762
# Epoch 130/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.4057 - accuracy: 0.3561 - val_loss: 1.8398 - val_accuracy: 0.5127
#
# Epoch 00130: val_loss did not improve from 1.83762
# Epoch 131/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 4.2921987187583e-05  Updated LR: 3.301691322121769e-05
# ====================================================
#
# 329/329 [==============================] - 218s 660ms/step - loss: 2.4209 - accuracy: 0.3552 - val_loss: 1.8369 - val_accuracy: 0.5148
#
# Epoch 00131: val_loss improved from 1.83762 to 1.83693, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 132/300
# 329/329 [==============================] - 217s 658ms/step - loss: 2.4007 - accuracy: 0.3520 - val_loss: 1.8371 - val_accuracy: 0.5158
#
# Epoch 00132: val_loss did not improve from 1.83693
# Epoch 133/300
# 329/329 [==============================] - 217s 659ms/step - loss: 2.4146 - accuracy: 0.3575 - val_loss: 1.8397 - val_accuracy: 0.5142
#
# Epoch 00133: val_loss did not improve from 1.83693
# Epoch 134/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.4109 - accuracy: 0.3587 - val_loss: 1.8372 - val_accuracy: 0.5173
#
# Epoch 00134: val_loss did not improve from 1.83693
# Epoch 135/300
# 329/329 [==============================] - 221s 670ms/step - loss: 2.4038 - accuracy: 0.3520 - val_loss: 1.8357 - val_accuracy: 0.5173
#
# ...
#
# Epoch 00139: val_loss did not improve from 1.83061
# Epoch 140/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.4186 - accuracy: 0.3510 - val_loss: 1.8290 - val_accuracy: 0.5161
#
# Epoch 00140: val_loss improved from 1.83061 to 1.82899, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 141/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 3.301691322121769e-05  Updated LR: 2.539762555478284e-05
# ====================================================
#
# 329/329 [==============================] - 220s 668ms/step - loss: 2.3954 - accuracy: 0.3626 - val_loss: 1.8335 - val_accuracy: 0.5145
#
# Epoch 00141: val_loss did not improve from 1.82899
# Epoch 142/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.4077 - accuracy: 0.3551 - val_loss: 1.8259 - val_accuracy: 0.5223
#
# Epoch 00142: val_loss improved from 1.82899 to 1.82589, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 143/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.3932 - accuracy: 0.3674 - val_loss: 1.8261 - val_accuracy: 0.5198
#
# Epoch 00143: val_loss did not improve from 1.82589
# Epoch 144/300
# 329/329 [==============================] - 219s 666ms/step - loss: 2.4045 - accuracy: 0.3532 - val_loss: 1.8290 - val_accuracy: 0.5176
#
# Epoch 00144: val_loss did not improve from 1.82589
# Epoch 145/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.4014 - accuracy: 0.3607 - val_loss: 1.8277 - val_accuracy: 0.5152
#
# Epoch 00145: val_loss did not improve from 1.82589
# Epoch 146/300
# 329/329 [==============================] - 221s 670ms/step - loss: 2.3888 - accuracy: 0.3591 - val_loss: 1.8255 - val_accuracy: 0.5192
#
# Epoch 00146: val_loss improved from 1.82589 to 1.82552, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 147/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.3773 - accuracy: 0.3639 - val_loss: 1.8230 - val_accuracy: 0.5192
#
# Epoch 00147: val_loss improved from 1.82552 to 1.82299, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 148/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.3758 - accuracy: 0.3666 - val_loss: 1.8261 - val_accuracy: 0.5182
#
# Epoch 00148: val_loss did not improve from 1.82299
# Epoch 149/300
# 329/329 [==============================] - 221s 671ms/step - loss: 2.4074 - accuracy: 0.3590 - val_loss: 1.8246 - val_accuracy: 0.5195
#
# Epoch 00149: val_loss did not improve from 1.82299
# Epoch 150/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.3745 - accuracy: 0.3663 - val_loss: 1.8223 - val_accuracy: 0.5232
#
# Epoch 00150: val_loss improved from 1.82299 to 1.82231, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 151/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 2.5397624995093793e-05  Updated LR: 1.953663461161061e-05
# ====================================================
#
# 329/329 [==============================] - 218s 661ms/step - loss: 2.3606 - accuracy: 0.3679 - val_loss: 1.8206 - val_accuracy: 0.5182
#
# Epoch 00151: val_loss improved from 1.82231 to 1.82064, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 152/300
# 329/329 [==============================] - 218s 661ms/step - loss: 2.3664 - accuracy: 0.3652 - val_loss: 1.8198 - val_accuracy: 0.5192
#
# Epoch 00152: val_loss improved from 1.82064 to 1.81981, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 153/300
# 329/329 [==============================] - 220s 667ms/step - loss: 2.3794 - accuracy: 0.3659 - val_loss: 1.8204 - val_accuracy: 0.5213
#
# Epoch 00153: val_loss did not improve from 1.81981
# Epoch 154/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.3864 - accuracy: 0.3616 - val_loss: 1.8201 - val_accuracy: 0.5204
#
# Epoch 00154: val_loss did not improve from 1.81981
# Epoch 155/300
# 329/329 [==============================] - 220s 668ms/step - loss: 2.3806 - accuracy: 0.3629 - val_loss: 1.8247 - val_accuracy: 0.5170
#
# Epoch 00155: val_loss did not improve from 1.81981
# Epoch 156/300
# 329/329 [==============================] - 219s 664ms/step - loss: 2.3835 - accuracy: 0.3632 - val_loss: 1.8224 - val_accuracy: 0.5229
#
# Epoch 00156: val_loss did not improve from 1.81981
# Epoch 157/300
# 329/329 [==============================] - 219s 665ms/step - loss: 2.3824 - accuracy: 0.3659 - val_loss: 1.8214 - val_accuracy: 0.5229
#
# Epoch 00157: val_loss did not improve from 1.81981
# Epoch 158/300
# 329/329 [==============================] - 218s 663ms/step - loss: 2.3731 - accuracy: 0.3627 - val_loss: 1.8206 - val_accuracy: 0.5226
#
# Epoch 00158: val_loss did not improve from 1.81981
# Epoch 159/300
# 329/329 [==============================] - 2445s 7s/step - loss: 2.4005 - accuracy: 0.3628 - val_loss: 1.8231 - val_accuracy: 0.5216
#
# Epoch 00159: val_loss did not improve from 1.81981
# Epoch 160/300
# 329/329 [==============================] - 1009s 3s/step - loss: 2.3967 - accuracy: 0.3594 - val_loss: 1.8215 - val_accuracy: 0.5220
#
# Epoch 00160: val_loss did not improve from 1.81981
# Epoch 161/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 1.953663377207704e-05  Updated LR: 1.5028179824674644e-05
# ====================================================
#
# 329/329 [==============================] - 234s 710ms/step - loss: 2.3836 - accuracy: 0.3643 - val_loss: 1.8215 - val_accuracy: 0.5207
#
# Epoch 00161: val_loss did not improve from 1.81981
# Epoch 162/300
# 329/329 [==============================] - 233s 708ms/step - loss: 2.3793 - accuracy: 0.3598 - val_loss: 1.8183 - val_accuracy: 0.5238
#
# Epoch 00162: val_loss improved from 1.81981 to 1.81834, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 163/300
# 329/329 [==============================] - 232s 705ms/step - loss: 2.3857 - accuracy: 0.3610 - val_loss: 1.8201 - val_accuracy: 0.5213
#
# Epoch 00163: val_loss did not improve from 1.81834
# Epoch 164/300
# 329/329 [==============================] - 233s 707ms/step - loss: 2.3898 - accuracy: 0.3587 - val_loss: 1.8210 - val_accuracy: 0.5220
#
# Epoch 00164: val_loss did not improve from 1.81834
# Epoch 165/300
# 329/329 [==============================] - 233s 708ms/step - loss: 2.3952 - accuracy: 0.3678 - val_loss: 1.8192 - val_accuracy: 0.5244
#
# Epoch 00165: val_loss did not improve from 1.81834
# Epoch 166/300
# 329/329 [==============================] - 232s 704ms/step - loss: 2.4051 - accuracy: 0.3584 - val_loss: 1.8207 - val_accuracy: 0.5223
#
# Epoch 00166: val_loss did not improve from 1.81834
# Epoch 167/300
# 329/329 [==============================] - 231s 702ms/step - loss: 2.3835 - accuracy: 0.3712 - val_loss: 1.8179 - val_accuracy: 0.5223
#
# Epoch 00167: val_loss improved from 1.81834 to 1.81788, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 168/300
# 329/329 [==============================] - 232s 703ms/step - loss: 2.3884 - accuracy: 0.3612 - val_loss: 1.8195 - val_accuracy: 0.5210
#
# Epoch 00168: val_loss did not improve from 1.81788
# Epoch 169/300
# 329/329 [==============================] - 232s 704ms/step - loss: 2.3974 - accuracy: 0.3606 - val_loss: 1.8185 - val_accuracy: 0.5223
#
# Epoch 00169: val_loss did not improve from 1.81788
# Epoch 170/300
# 329/329 [==============================] - 232s 704ms/step - loss: 2.3816 - accuracy: 0.3644 - val_loss: 1.8193 - val_accuracy: 0.5223
#
# Epoch 00170: val_loss did not improve from 1.81788
# Epoch 171/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 1.502817940490786e-05  Updated LR: 1.1560138003775277e-05
# ====================================================
#
# 329/329 [==============================] - 232s 703ms/step - loss: 2.3857 - accuracy: 0.3654 - val_loss: 1.8201 - val_accuracy: 0.5220
#
# Epoch 00171: val_loss did not improve from 1.81788
# Epoch 172/300
# 329/329 [==============================] - 231s 702ms/step - loss: 2.3815 - accuracy: 0.3671 - val_loss: 1.8182 - val_accuracy: 0.5223
#
# Epoch 00172: val_loss did not improve from 1.81788
# Epoch 173/300
# 329/329 [==============================] - 232s 705ms/step - loss: 2.3701 - accuracy: 0.3673 - val_loss: 1.8159 - val_accuracy: 0.5223
#
# Epoch 00173: val_loss improved from 1.81788 to 1.81591, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 174/300
# 329/329 [==============================] - 232s 704ms/step - loss: 2.3746 - accuracy: 0.3707 - val_loss: 1.8167 - val_accuracy: 0.5232
#
# Epoch 00174: val_loss did not improve from 1.81591
# Epoch 175/300
# 329/329 [==============================] - 231s 701ms/step - loss: 2.3693 - accuracy: 0.3634 - val_loss: 1.8146 - val_accuracy: 0.5223
#
# Epoch 00175: val_loss improved from 1.81591 to 1.81461, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 176/300
# 329/329 [==============================] - 231s 701ms/step - loss: 2.3793 - accuracy: 0.3644 - val_loss: 1.8166 - val_accuracy: 0.5204
#
# Epoch 00176: val_loss did not improve from 1.81461
# Epoch 177/300
# 329/329 [==============================] - 231s 701ms/step - loss: 2.3835 - accuracy: 0.3614 - val_loss: 1.8166 - val_accuracy: 0.5207
#
# Epoch 00177: val_loss did not improve from 1.81461
# Epoch 178/300
# 329/329 [==============================] - 231s 701ms/step - loss: 2.3632 - accuracy: 0.3626 - val_loss: 1.8147 - val_accuracy: 0.5210
#
# Epoch 00178: val_loss did not improve from 1.81461
# Epoch 179/300
# 329/329 [==============================] - 231s 701ms/step - loss: 2.3691 - accuracy: 0.3619 - val_loss: 1.8127 - val_accuracy: 0.5210
#
# Epoch 00179: val_loss improved from 1.81461 to 1.81274, saving model to C:\Users\Braden\Desktop\Data_Science\04_General_Assembly\05_Projects\03_car\trained_models/convnet\2021_07_20-13_14_36_resnet101_arch1_lrdecay_E300_Oadam001_B32.keras
# Epoch 180/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3689 - accuracy: 0.3641 - val_loss: 1.8132 - val_accuracy: 0.5235
#
# Epoch 00180: val_loss did not improve from 1.81274
# Epoch 181/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 1.1560137863853015e-05  Updated LR: 8.892413741425396e-06
# ====================================================
#
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3922 - accuracy: 0.3579 - val_loss: 1.8133 - val_accuracy: 0.5223
#
# Epoch 00181: val_loss did not improve from 1.81274
# Epoch 182/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3720 - accuracy: 0.3643 - val_loss: 1.8150 - val_accuracy: 0.5220
#
# Epoch 00182: val_loss did not improve from 1.81274
# Epoch 183/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3926 - accuracy: 0.3618 - val_loss: 1.8168 - val_accuracy: 0.5223
#
# Epoch 00183: val_loss did not improve from 1.81274
# Epoch 184/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3913 - accuracy: 0.3611 - val_loss: 1.8159 - val_accuracy: 0.5210
#
# Epoch 00184: val_loss did not improve from 1.81274
# Epoch 185/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3775 - accuracy: 0.3649 - val_loss: 1.8153 - val_accuracy: 0.5210
#
# Epoch 00185: val_loss did not improve from 1.81274
# Epoch 186/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3661 - accuracy: 0.3672 - val_loss: 1.8146 - val_accuracy: 0.5210
#
# Epoch 00186: val_loss did not improve from 1.81274
# Epoch 187/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3832 - accuracy: 0.3591 - val_loss: 1.8155 - val_accuracy: 0.5223
#
# Epoch 00187: val_loss did not improve from 1.81274
# Epoch 188/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3792 - accuracy: 0.3624 - val_loss: 1.8158 - val_accuracy: 0.5223
#
# Epoch 00188: val_loss did not improve from 1.81274
# Epoch 189/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3709 - accuracy: 0.3669 - val_loss: 1.8161 - val_accuracy: 0.5204
#
# Epoch 00189: val_loss did not improve from 1.81274
# Epoch 190/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3729 - accuracy: 0.3611 - val_loss: 1.8169 - val_accuracy: 0.5198
#
# Epoch 00190: val_loss did not improve from 1.81274
# Epoch 191/300
# /n====================================================
# Updating the learning rate...
# Previous LR: 8.892413461580873e-06  Updated LR: 6.840318047369901e-06
# ====================================================
#
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3599 - accuracy: 0.3704 - val_loss: 1.8155 - val_accuracy: 0.5213
#
# Epoch 00191: val_loss did not improve from 1.81274
# Epoch 192/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3686 - accuracy: 0.3676 - val_loss: 1.8142 - val_accuracy: 0.5220
#
# Epoch 00192: val_loss did not improve from 1.81274
# Epoch 193/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3886 - accuracy: 0.3645 - val_loss: 1.8138 - val_accuracy: 0.5220
#
# Epoch 00193: val_loss did not improve from 1.81274
# Epoch 194/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3827 - accuracy: 0.3640 - val_loss: 1.8148 - val_accuracy: 0.5229
#
# Epoch 00194: val_loss did not improve from 1.81274
# Epoch 195/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3616 - accuracy: 0.3668 - val_loss: 1.8134 - val_accuracy: 0.5223
#
# Epoch 00195: val_loss did not improve from 1.81274
# Epoch 196/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3758 - accuracy: 0.3751 - val_loss: 1.8133 - val_accuracy: 0.5220
#
# Epoch 00196: val_loss did not improve from 1.81274
# Epoch 197/300
# 329/329 [==============================] - 230s 698ms/step - loss: 2.3618 - accuracy: 0.3664 - val_loss: 1.8130 - val_accuracy: 0.5226
#
# Epoch 00197: val_loss did not improve from 1.81274
# Epoch 198/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3685 - accuracy: 0.3649 - val_loss: 1.8139 - val_accuracy: 0.5220
#
# Epoch 00198: val_loss did not improve from 1.81274
# Epoch 199/300
# 329/329 [==============================] - 230s 699ms/step - loss: 2.3665 - accuracy: 0.3693 - val_loss: 1.8134 - val_accuracy: 0.5229
#
# Epoch 00199: val_loss did not improve from 1.81274
# Epoch 00199: early stopping
# 76/76 [==============================] - 42s 529ms/step - loss: 1.8200 - accuracy: 0.5339
#
# ========================== Model Test Results ===============================
# Test Accuracy: 0.5339366793632507
# Test Loss: 1.8199946880340576
# =============================================================================
